# %%
import sys
sys.path.append("/afs/cs.stanford.edu/u/anenberg/scr/caffe/python/")
import caffe

# %%
import os
caffe_root = "/afs/cs.stanford.edu/u/anenberg/scr/caffe"

# %%
root_path = '/afs/cs.stanford.edu/u/anenberg/scr/CS231N/'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Set the right path to your model definition file, pretrained model weights,
# and the image you would like to classify.
#MODEL_FILE = '../caffe/models/bvlc_reference_caffenet/deploy.prototxt'
#MODEL_FILE = os.path.join(root_path, 'models', 'imagenet', 'cifar10_quick_train_test.prototxt')
VAL_DATA_ROOT='/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Training/firstFrame_val/'
MODEL_FILE = './examples/UCFff/quick.prototxt'

#PRETRAINED = '../caffe/models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel'
#PRETRAINED = os.path.join(root_path, 'models', 'imagenet', 'caffenet_train_iter_2000.caffemodel')
PRETRAINED = './examples/UCFff/quick_iter_2000.caffemodel'

IMAGE_FILE = os.path.join(VAL_DATA_ROOT, 'v_Haircut_g06_c01.jpeg')
MEAN_FILE = './examples/UCFff/mean.npy'

# %%
import pandas as pd
import random

df = pd.read_csv('../../scr/CS231N/data/UCFff/UCF_test.txt', delimiter=' ', header=None, names=['filenames', 'class_id'])
sample = df.ix[random.sample(df.index, 1000)]
y = sample.class_id.values

# %%
with open('/afs/cs.stanford.edu/u/anenberg/scr/CS231N/examples/UCFff/tmp.out', 'r+') as f:
    allftrs = pickle.load(f)
    
tester_pred = np.argmax(allftrs, axis=1)

# %%
pwd
# Out:
# u'/afs/cs.stanford.edu/u/anenberg/scr/CS231N'

# %%
np.mean(tester_pred == df.class_id)
# Out:
# 0.047277227722772278

# %%
len(input_images)
# Out:
# 4040

# %%
# select images
import glob, random, os
images = [os.path.join(VAL_DATA_ROOT, image_filename) for image_filename in df.filenames.values]
# use the first 10 images for the image subset
len(images)
# Out:
# 4040

# %% [markdown]
# Loading a network is easy. caffe.Classifier takes care of everything. Note the arguments for configuring input preprocessing: mean subtraction switched on by giving a mean array, input channel swapping takes care of mapping RGB into the reference ImageNet model's BGR order, and raw scaling multiplies the feature scale from the input [0,1] to the ImageNet model's [0,255].
#
# We will set the phase to test since we are doing testing, and will first use CPU for the computation.

# %%
caffe.set_phase_test()
caffe.set_mode_cpu()
net = caffe.Classifier(MODEL_FILE, PRETRAINED,
                       mean=np.load(MEAN_FILE),
                       raw_scale=255,
                       image_dims=(32, 32))

# %%
print 'hello'
# Out:
# hello

# %% [markdown]
# Let's take a look at our example image with Caffe's image loading helper.

# %%
input_images = [caffe.io.load_image(IMAGE_FILE) for IMAGE_FILE in images]
"""
for input_image in input_images:
    plt.figure()
    plt.imshow(input_image)
"""
# Out:
# '\nfor input_image in input_images:\n    plt.figure()\n    plt.imshow(input_image)\n'

# %% [markdown]
# Time to classify. The default is to actually do 10 predictions, cropping the center and corners of the image as well as their mirrored versions, and average over the predictions:

# %%
prediction = net.predict(input_images)  # predict takes any number of images, and formats them for the Caffe net automatically
"""
for i in range(len(input_images)):
    print 'prediction shape:', prediction[i].shape
    plt.figure()
    plt.plot(prediction[i])
    plt.title('Image %d: %s - Predicted Class: %d'%(i, os.path.basename(image_subset[i]), prediction[i].argmax()))
    print 'predicted class:', prediction[i].argmax()
    print 'class score', max(prediction[i])
"""
# Out:
# In for ix, in_ in enumerate(inputs): 0 4040
# In for ix, in_ in enumerate(inputs): 1 4040
# In for ix, in_ in enumerate(inputs): 2 4040
# In for ix, in_ in enumerate(inputs): 3 4040
# In for ix, in_ in enumerate(inputs): 4 4040
# In for ix, in_ in enumerate(inputs): 5 4040
# In for ix, in_ in enumerate(inputs): 6 4040
# In for ix, in_ in enumerate(inputs): 7 4040
# In for ix, in_ in enumerate(inputs): 8 4040
# In for ix, in_ in enumerate(inputs): 9 4040
# In for ix, in_ in enumerate(inputs): 10 4040
# In for ix, in_ in enumerate(inputs): 11 4040
# In for ix, in_ in enumerate(inputs): 12 4040
# In for ix, in_ in enumerate(inputs): 13 4040
# In for ix, in_ in enumerate(inputs): 14 4040
# In for ix, in_ in enumerate(inputs): 15 4040
# In for ix, in_ in enumerate(inputs): 16 4040
# In for ix, in_ in enumerate(inputs): 17 4040
# In for ix, in_ in enumerate(inputs): 18 4040
# In for ix, in_ in enumerate(inputs): 19 4040
# In for ix, in_ in enumerate(inputs): 20 4040
# In for ix, in_ in enumerate(inputs): 21 4040
# In for ix, in_ in enumerate(inputs): 22 4040
# In for ix, in_ in enumerate(inputs): 23 4040
# In for ix, in_ in enumerate(inputs): 24 4040
# In for ix, in_ in enumerate(inputs): 25 4040
# In for ix, in_ in enumerate(inputs): 26 4040
# In for ix, in_ in enumerate(inputs): 27 4040
# In for ix, in_ in enumerate(inputs): 28 4040
# In for ix, in_ in enumerate(inputs): 29 4040
# In for ix, in_ in enumerate(inputs): 30 4040
# In for ix, in_ in enumerate(inputs): 31 4040
# In for ix, in_ in enumerate(inputs): 32 4040
# In for ix, in_ in enumerate(inputs): 33 4040
# In for ix, in_ in enumerate(inputs): 34 4040
# In for ix, in_ in enumerate(inputs): 35 4040
# In for ix, in_ in enumerate(inputs): 36 4040
# In for ix, in_ in enumerate(inputs): 37 4040
# In for ix, in_ in enumerate(inputs): 38 4040
# In for ix, in_ in enumerate(inputs): 39 4040
# In for ix, in_ in enumerate(inputs): 40 4040
# In for ix, in_ in enumerate(inputs): 41 4040
# In for ix, in_ in enumerate(inputs): 42 4040
# In for ix, in_ in enumerate(inputs): 43 4040
# In for ix, in_ in enumerate(inputs): 44 4040
# In for ix, in_ in enumerate(inputs): 45 4040
# In for ix, in_ in enumerate(inputs): 46 4040
# In for ix, in_ in enumerate(inputs): 47 4040
# In for ix, in_ in enumerate(inputs): 48 4040
# In for ix, in_ in enumerate(inputs): 49 4040
# In for ix, in_ in enumerate(inputs): 50 4040
# In for ix, in_ in enumerate(inputs): 51 4040
# In for ix, in_ in enumerate(inputs): 52 4040
# In for ix, in_ in enumerate(inputs): 53 4040
# In for ix, in_ in enumerate(inputs): 54 4040
# In for ix, in_ in enumerate(inputs): 55 4040
# In for ix, in_ in enumerate(inputs): 56 4040
# In for ix, in_ in enumerate(inputs): 57 4040
# In for ix, in_ in enumerate(inputs): 58 4040
# In for ix, in_ in enumerate(inputs): 59 4040
# In for ix, in_ in enumerate(inputs): 60 4040
# In for ix, in_ in enumerate(inputs): 61 4040
# In for ix, in_ in enumerate(inputs): 62 4040
# In for ix, in_ in enumerate(inputs): 63 4040
# In for ix, in_ in enumerate(inputs): 64 4040
# In for ix, in_ in enumerate(inputs): 65 4040
# In for ix, in_ in enumerate(inputs): 66 4040
# In for ix, in_ in enumerate(inputs): 67 4040
# In for ix, in_ in enumerate(inputs): 68 4040
# In for ix, in_ in enumerate(inputs): 69 4040
# In for ix, in_ in enumerate(inputs): 70 4040
# In for ix, in_ in enumerate(inputs): 71 4040
# In for ix, in_ in enumerate(inputs): 72 4040
# In for ix, in_ in enumerate(inputs): 73 4040
# In for ix, in_ in enumerate(inputs): 74 4040
# In for ix, in_ in enumerate(inputs): 75 4040
# In for ix, in_ in enumerate(inputs): 76 4040
# In for ix, in_ in enumerate(inputs): 77 4040
# In for ix, in_ in enumerate(inputs): 78 4040
# In for ix, in_ in enumerate(inputs): 79 4040
# In for ix, in_ in enumerate(inputs): 80 4040
# In for ix, in_ in enumerate(inputs): 81 4040
# In for ix, in_ in enumerate(inputs): 82 4040
# In for ix, in_ in enumerate(inputs): 83 4040
# In for ix, in_ in enumerate(inputs): 84 4040
# In for ix, in_ in enumerate(inputs): 85 4040
# In for ix, in_ in enumerate(inputs): 86 4040
# In for ix, in_ in enumerate(inputs): 87 4040
# In for ix, in_ in enumerate(inputs): 88 4040
# In for ix, in_ in enumerate(inputs): 89 4040
# In for ix, in_ in enumerate(inputs): 90 4040
# In for ix, in_ in enumerate(inputs): 91 4040
# In for ix, in_ in enumerate(inputs): 92 4040
# In for ix, in_ in enumerate(inputs): 93 4040
# In for ix, in_ in enumerate(inputs): 94 4040
# In for ix, in_ in enumerate(inputs): 95 4040
# In for ix, in_ in enumerate(inputs): 96 4040
# In for ix, in_ in enumerate(inputs): 97 4040
# In for ix, in_ in enumerate(inputs): 98 4040
# In for ix, in_ in enumerate(inputs): 99 4040
# In for ix, in_ in enumerate(inputs): 100 4040
# In for ix, in_ in enumerate(inputs): 101 4040
# In for ix, in_ in enumerate(inputs): 102 4040
# In for ix, in_ in enumerate(inputs): 103 4040
# In for ix, in_ in enumerate(inputs): 104 4040
# In for ix, in_ in enumerate(inputs): 105 4040
# In for ix, in_ in enumerate(inputs): 106 4040
# In for ix, in_ in enumerate(inputs): 107 4040
# In for ix, in_ in enumerate(inputs): 108 4040
# In for ix, in_ in enumerate(inputs): 109 4040
# In for ix, in_ in enumerate(inputs): 110 4040
# In for ix, in_ in enumerate(inputs): 111 4040
# In for ix, in_ in enumerate(inputs): 112 4040
# In for ix, in_ in enumerate(inputs): 113 4040
# In for ix, in_ in enumerate(inputs): 114 4040
# In for ix, in_ in enumerate(inputs): 115 4040
# In for ix, in_ in enumerate(inputs): 116 4040
# In for ix, in_ in enumerate(inputs): 117 4040
# In for ix, in_ in enumerate(inputs): 118 4040
# In for ix, in_ in enumerate(inputs): 119 4040
# In for ix, in_ in enumerate(inputs): 120 4040
# In for ix, in_ in enumerate(inputs): 121 4040
# In for ix, in_ in enumerate(inputs): 122 4040
# In for ix, in_ in enumerate(inputs): 123 4040
# In for ix, in_ in enumerate(inputs): 124 4040
# In for ix, in_ in enumerate(inputs): 125 4040
# In for ix, in_ in enumerate(inputs): 126 4040
# In for ix, in_ in enumerate(inputs): 127 4040
# In for ix, in_ in enumerate(inputs): 128 4040
# In for ix, in_ in enumerate(inputs): 129 4040
# In for ix, in_ in enumerate(inputs): 130 4040
# In for ix, in_ in enumerate(inputs): 131 4040
# In for ix, in_ in enumerate(inputs): 132 4040
# In for ix, in_ in enumerate(inputs): 133 4040
# In for ix, in_ in enumerate(inputs): 134 4040
# In for ix, in_ in enumerate(inputs): 135 4040
# In for ix, in_ in enumerate(inputs): 136 4040
# In for ix, in_ in enumerate(inputs): 137 4040
# In for ix, in_ in enumerate(inputs): 138 4040
# In for ix, in_ in enumerate(inputs): 139 4040
# In for ix, in_ in enumerate(inputs): 140 4040
# In for ix, in_ in enumerate(inputs): 141 4040
# In for ix, in_ in enumerate(inputs): 142 4040
# In for ix, in_ in enumerate(inputs): 143 4040
# In for ix, in_ in enumerate(inputs): 144 4040
# In for ix, in_ in enumerate(inputs): 145 4040
# In for ix, in_ in enumerate(inputs): 146 4040
# In for ix, in_ in enumerate(inputs): 147 4040
# In for ix, in_ in enumerate(inputs): 148 4040
# In for ix, in_ in enumerate(inputs): 149 4040
# In for ix, in_ in enumerate(inputs): 150 4040
# In for ix, in_ in enumerate(inputs): 151 4040
# In for ix, in_ in enumerate(inputs): 152 4040
# In for ix, in_ in enumerate(inputs): 153 4040
# In for ix, in_ in enumerate(inputs): 154 4040
# In for ix, in_ in enumerate(inputs): 155 4040
# In for ix, in_ in enumerate(inputs): 156 4040
# In for ix, in_ in enumerate(inputs): 157 4040
# In for ix, in_ in enumerate(inputs): 158 4040
# In for ix, in_ in enumerate(inputs): 159 4040
# In for ix, in_ in enumerate(inputs): 160 4040
# In for ix, in_ in enumerate(inputs): 161 4040
# In for ix, in_ in enumerate(inputs): 162 4040
# In for ix, in_ in enumerate(inputs): 163 4040
# In for ix, in_ in enumerate(inputs): 164 4040
# In for ix, in_ in enumerate(inputs): 165 4040
# In for ix, in_ in enumerate(inputs): 166 4040
# In for ix, in_ in enumerate(inputs): 167 4040
# In for ix, in_ in enumerate(inputs): 168 4040
# In for ix, in_ in enumerate(inputs): 169 4040
# In for ix, in_ in enumerate(inputs): 170 4040
# In for ix, in_ in enumerate(inputs): 171 4040
# In for ix, in_ in enumerate(inputs): 172 4040
# In for ix, in_ in enumerate(inputs): 173 4040
# In for ix, in_ in enumerate(inputs): 174 4040
# In for ix, in_ in enumerate(inputs): 175 4040
# In for ix, in_ in enumerate(inputs): 176 4040
# In for ix, in_ in enumerate(inputs): 177 4040
# In for ix, in_ in enumerate(inputs): 178 4040
# In for ix, in_ in enumerate(inputs): 179 4040
# In for ix, in_ in enumerate(inputs): 180 4040
# In for ix, in_ in enumerate(inputs): 181 4040
# In for ix, in_ in enumerate(inputs): 182 4040
# In for ix, in_ in enumerate(inputs): 183 4040
# In for ix, in_ in enumerate(inputs): 184 4040
# In for ix, in_ in enumerate(inputs): 185 4040
# In for ix, in_ in enumerate(inputs): 186 4040
# In for ix, in_ in enumerate(inputs): 187 4040
# In for ix, in_ in enumerate(inputs): 188 4040
# In for ix, in_ in enumerate(inputs): 189 4040
# In for ix, in_ in enumerate(inputs): 190 4040
# In for ix, in_ in enumerate(inputs): 191 4040
# In for ix, in_ in enumerate(inputs): 192 4040
# In for ix, in_ in enumerate(inputs): 193 4040
# In for ix, in_ in enumerate(inputs): 194 4040
# In for ix, in_ in enumerate(inputs): 195 4040
# In for ix, in_ in enumerate(inputs): 196 4040
# In for ix, in_ in enumerate(inputs): 197 4040
# In for ix, in_ in enumerate(inputs): 198 4040
# In for ix, in_ in enumerate(inputs): 199 4040
# In for ix, in_ in enumerate(inputs): 200 4040
# In for ix, in_ in enumerate(inputs): 201 4040
# In for ix, in_ in enumerate(inputs): 202 4040
# In for ix, in_ in enumerate(inputs): 203 4040
# In for ix, in_ in enumerate(inputs): 204 4040
# In for ix, in_ in enumerate(inputs): 205 4040
# In for ix, in_ in enumerate(inputs): 206 4040
# In for ix, in_ in enumerate(inputs): 207 4040
# In for ix, in_ in enumerate(inputs): 208 4040
# In for ix, in_ in enumerate(inputs): 209 4040
# In for ix, in_ in enumerate(inputs): 210 4040
# In for ix, in_ in enumerate(inputs): 211 4040
# In for ix, in_ in enumerate(inputs): 212 4040
# In for ix, in_ in enumerate(inputs): 213 4040
# In for ix, in_ in enumerate(inputs): 214 4040
# In for ix, in_ in enumerate(inputs): 215 4040
# In for ix, in_ in enumerate(inputs): 216 4040
# In for ix, in_ in enumerate(inputs): 217 4040
# In for ix, in_ in enumerate(inputs): 218 4040
# In for ix, in_ in enumerate(inputs): 219 4040
# In for ix, in_ in enumerate(inputs): 220 4040
# In for ix, in_ in enumerate(inputs): 221 4040
# In for ix, in_ in enumerate(inputs): 222 4040
# In for ix, in_ in enumerate(inputs): 223 4040
# In for ix, in_ in enumerate(inputs): 224 4040
# In for ix, in_ in enumerate(inputs): 225 4040
# In for ix, in_ in enumerate(inputs): 226 4040
# In for ix, in_ in enumerate(inputs): 227 4040
# In for ix, in_ in enumerate(inputs): 228 4040
# In for ix, in_ in enumerate(inputs): 229 4040
# In for ix, in_ in enumerate(inputs): 230 4040
# In for ix, in_ in enumerate(inputs): 231 4040
# In for ix, in_ in enumerate(inputs): 232 4040
# In for ix, in_ in enumerate(inputs): 233 4040
# In for ix, in_ in enumerate(inputs): 234 4040
# In for ix, in_ in enumerate(inputs): 235 4040
# In for ix, in_ in enumerate(inputs): 236 4040
# In for ix, in_ in enumerate(inputs): 237 4040
# In for ix, in_ in enumerate(inputs): 238 4040
# In for ix, in_ in enumerate(inputs): 239 4040
# In for ix, in_ in enumerate(inputs): 240 4040
# In for ix, in_ in enumerate(inputs): 241 4040
# In for ix, in_ in enumerate(inputs): 242 4040
# In for ix, in_ in enumerate(inputs): 243 4040
# In for ix, in_ in enumerate(inputs): 244 4040
# In for ix, in_ in enumerate(inputs): 245 4040
# In for ix, in_ in enumerate(inputs): 246 4040
# In for ix, in_ in enumerate(inputs): 247 4040
# In for ix, in_ in enumerate(inputs): 248 4040
# In for ix, in_ in enumerate(inputs): 249 4040
# In for ix, in_ in enumerate(inputs): 250 4040
# In for ix, in_ in enumerate(inputs): 251 4040
# In for ix, in_ in enumerate(inputs): 252 4040
# In for ix, in_ in enumerate(inputs): 253 4040
# In for ix, in_ in enumerate(inputs): 254 4040
# In for ix, in_ in enumerate(inputs): 255 4040
# In for ix, in_ in enumerate(inputs): 256 4040
# In for ix, in_ in enumerate(inputs): 257 4040
# In for ix, in_ in enumerate(inputs): 258 4040
# In for ix, in_ in enumerate(inputs): 259 4040
# In for ix, in_ in enumerate(inputs): 260 4040
# In for ix, in_ in enumerate(inputs): 261 4040
# In for ix, in_ in enumerate(inputs): 262 4040
# In for ix, in_ in enumerate(inputs): 263 4040
# In for ix, in_ in enumerate(inputs): 264 4040
# In for ix, in_ in enumerate(inputs): 265 4040
# In for ix, in_ in enumerate(inputs): 266 4040
# In for ix, in_ in enumerate(inputs): 267 4040
# In for ix, in_ in enumerate(inputs): 268 4040
# In for ix, in_ in enumerate(inputs): 269 4040
# In for ix, in_ in enumerate(inputs): 270 4040
# In for ix, in_ in enumerate(inputs): 271 4040
# In for ix, in_ in enumerate(inputs): 272 4040
# In for ix, in_ in enumerate(inputs): 273 4040
# In for ix, in_ in enumerate(inputs): 274 4040
# In for ix, in_ in enumerate(inputs): 275 4040
# In for ix, in_ in enumerate(inputs): 276 4040
# In for ix, in_ in enumerate(inputs): 277 4040
# In for ix, in_ in enumerate(inputs): 278 4040
# In for ix, in_ in enumerate(inputs): 279 4040
# In for ix, in_ in enumerate(inputs): 280 4040
# In for ix, in_ in enumerate(inputs): 281 4040
# In for ix, in_ in enumerate(inputs): 282 4040
# In for ix, in_ in enumerate(inputs): 283 4040
# In for ix, in_ in enumerate(inputs): 284 4040
# In for ix, in_ in enumerate(inputs): 285 4040
# In for ix, in_ in enumerate(inputs): 286 4040
# In for ix, in_ in enumerate(inputs): 287 4040
# In for ix, in_ in enumerate(inputs): 288 4040
# In for ix, in_ in enumerate(inputs): 289 4040
# In for ix, in_ in enumerate(inputs): 290 4040
# In for ix, in_ in enumerate(inputs): 291 4040
# In for ix, in_ in enumerate(inputs): 292 4040
# In for ix, in_ in enumerate(inputs): 293 4040
# In for ix, in_ in enumerate(inputs): 294 4040
# In for ix, in_ in enumerate(inputs): 295 4040
# In for ix, in_ in enumerate(inputs): 296 4040
# In for ix, in_ in enumerate(inputs): 297 4040
# In for ix, in_ in enumerate(inputs): 298 4040
# In for ix, in_ in enumerate(inputs): 299 4040
# In for ix, in_ in enumerate(inputs): 300 4040
# In for ix, in_ in enumerate(inputs): 301 4040
# In for ix, in_ in enumerate(inputs): 302 4040
# In for ix, in_ in enumerate(inputs): 303 4040
# In for ix, in_ in enumerate(inputs): 304 4040
# In for ix, in_ in enumerate(inputs): 305 4040
# In for ix, in_ in enumerate(inputs): 306 4040
# In for ix, in_ in enumerate(inputs): 307 4040
# In for ix, in_ in enumerate(inputs): 308 4040
# In for ix, in_ in enumerate(inputs): 309 4040
# In for ix, in_ in enumerate(inputs): 310 4040
# In for ix, in_ in enumerate(inputs): 311 4040
# In for ix, in_ in enumerate(inputs): 312 4040
# In for ix, in_ in enumerate(inputs): 313 4040
# In for ix, in_ in enumerate(inputs): 314 4040
# In for ix, in_ in enumerate(inputs): 315 4040
# In for ix, in_ in enumerate(inputs): 316 4040
# In for ix, in_ in enumerate(inputs): 317 4040
# In for ix, in_ in enumerate(inputs): 318 4040
# In for ix, in_ in enumerate(inputs): 319 4040
# In for ix, in_ in enumerate(inputs): 320 4040
# In for ix, in_ in enumerate(inputs): 321 4040
# In for ix, in_ in enumerate(inputs): 322 4040
# In for ix, in_ in enumerate(inputs): 323 4040
# In for ix, in_ in enumerate(inputs): 324 4040
# In for ix, in_ in enumerate(inputs): 325 4040
# In for ix, in_ in enumerate(inputs): 326 4040
# In for ix, in_ in enumerate(inputs): 327 4040
# In for ix, in_ in enumerate(inputs): 328 4040
# In for ix, in_ in enumerate(inputs): 329 4040
# In for ix, in_ in enumerate(inputs): 330 4040
# In for ix, in_ in enumerate(inputs): 331 4040
# In for ix, in_ in enumerate(inputs): 332 4040
# In for ix, in_ in enumerate(inputs): 333 4040
# In for ix, in_ in enumerate(inputs): 334 4040
# In for ix, in_ in enumerate(inputs): 335 4040
# In for ix, in_ in enumerate(inputs): 336 4040
# In for ix, in_ in enumerate(inputs): 337 4040
# In for ix, in_ in enumerate(inputs): 338 4040
# In for ix, in_ in enumerate(inputs): 339 4040
# In for ix, in_ in enumerate(inputs): 340 4040
# In for ix, in_ in enumerate(inputs): 341 4040
# In for ix, in_ in enumerate(inputs): 342 4040
# In for ix, in_ in enumerate(inputs): 343 4040
# In for ix, in_ in enumerate(inputs): 344 4040
# In for ix, in_ in enumerate(inputs): 345 4040
# In for ix, in_ in enumerate(inputs): 346 4040
# In for ix, in_ in enumerate(inputs): 347 4040
# In for ix, in_ in enumerate(inputs): 348 4040
# In for ix, in_ in enumerate(inputs): 349 4040
# In for ix, in_ in enumerate(inputs): 350 4040
# In for ix, in_ in enumerate(inputs): 351 4040
# In for ix, in_ in enumerate(inputs): 352 4040
# In for ix, in_ in enumerate(inputs): 353 4040
# In for ix, in_ in enumerate(inputs): 354 4040
# In for ix, in_ in enumerate(inputs): 355 4040
# In for ix, in_ in enumerate(inputs): 356 4040
# In for ix, in_ in enumerate(inputs): 357 4040
# In for ix, in_ in enumerate(inputs): 358 4040
# In for ix, in_ in enumerate(inputs): 359 4040
# In for ix, in_ in enumerate(inputs): 360 4040
# In for ix, in_ in enumerate(inputs): 361 4040
# In for ix, in_ in enumerate(inputs): 362 4040
# In for ix, in_ in enumerate(inputs): 363 4040
# In for ix, in_ in enumerate(inputs): 364 4040
# In for ix, in_ in enumerate(inputs): 365 4040
# In for ix, in_ in enumerate(inputs): 366 4040
# In for ix, in_ in enumerate(inputs): 367 4040
# In for ix, in_ in enumerate(inputs): 368 4040
# In for ix, in_ in enumerate(inputs): 369 4040
# In for ix, in_ in enumerate(inputs): 370 4040
# In for ix, in_ in enumerate(inputs): 371 4040
# In for ix, in_ in enumerate(inputs): 372 4040
# In for ix, in_ in enumerate(inputs): 373 4040
# In for ix, in_ in enumerate(inputs): 374 4040
# In for ix, in_ in enumerate(inputs): 375 4040
# In for ix, in_ in enumerate(inputs): 376 4040
# In for ix, in_ in enumerate(inputs): 377 4040
# In for ix, in_ in enumerate(inputs): 378 4040
# In for ix, in_ in enumerate(inputs): 379 4040
# In for ix, in_ in enumerate(inputs): 380 4040
# In for ix, in_ in enumerate(inputs): 381 4040
# In for ix, in_ in enumerate(inputs): 382 4040
# In for ix, in_ in enumerate(inputs): 383 4040
# In for ix, in_ in enumerate(inputs): 384 4040
# In for ix, in_ in enumerate(inputs): 385 4040
# In for ix, in_ in enumerate(inputs): 386 4040
# In for ix, in_ in enumerate(inputs): 387 4040
# In for ix, in_ in enumerate(inputs): 388 4040
# In for ix, in_ in enumerate(inputs): 389 4040
# In for ix, in_ in enumerate(inputs): 390 4040
# In for ix, in_ in enumerate(inputs): 391 4040
# In for ix, in_ in enumerate(inputs): 392 4040
# In for ix, in_ in enumerate(inputs): 393 4040
# In for ix, in_ in enumerate(inputs): 394 4040
# In for ix, in_ in enumerate(inputs): 395 4040
# In for ix, in_ in enumerate(inputs): 396 4040
# In for ix, in_ in enumerate(inputs): 397 4040
# In for ix, in_ in enumerate(inputs): 398 4040
# In for ix, in_ in enumerate(inputs): 399 4040
# In for ix, in_ in enumerate(inputs): 400 4040
# In for ix, in_ in enumerate(inputs): 401 4040
# In for ix, in_ in enumerate(inputs): 402 4040
# In for ix, in_ in enumerate(inputs): 403 4040
# In for ix, in_ in enumerate(inputs): 404 4040
# In for ix, in_ in enumerate(inputs): 405 4040
# In for ix, in_ in enumerate(inputs): 406 4040
# In for ix, in_ in enumerate(inputs): 407 4040
# In for ix, in_ in enumerate(inputs): 408 4040
# In for ix, in_ in enumerate(inputs): 409 4040
# In for ix, in_ in enumerate(inputs): 410 4040
# In for ix, in_ in enumerate(inputs): 411 4040
# In for ix, in_ in enumerate(inputs): 412 4040
# In for ix, in_ in enumerate(inputs): 413 4040
# In for ix, in_ in enumerate(inputs): 414 4040
# In for ix, in_ in enumerate(inputs): 415 4040
# In for ix, in_ in enumerate(inputs): 416 4040
# In for ix, in_ in enumerate(inputs): 417 4040
# In for ix, in_ in enumerate(inputs): 418 4040
# In for ix, in_ in enumerate(inputs): 419 4040
# In for ix, in_ in enumerate(inputs): 420 4040
# In for ix, in_ in enumerate(inputs): 421 4040
# In for ix, in_ in enumerate(inputs): 422 4040
# In for ix, in_ in enumerate(inputs): 423 4040
# In for ix, in_ in enumerate(inputs): 424 4040
# In for ix, in_ in enumerate(inputs): 425 4040
# In for ix, in_ in enumerate(inputs): 426 4040
# In for ix, in_ in enumerate(inputs): 427 4040
# In for ix, in_ in enumerate(inputs): 428 4040
# In for ix, in_ in enumerate(inputs): 429 4040
# In for ix, in_ in enumerate(inputs): 430 4040
# In for ix, in_ in enumerate(inputs): 431 4040
# In for ix, in_ in enumerate(inputs): 432 4040
# In for ix, in_ in enumerate(inputs): 433 4040
# In for ix, in_ in enumerate(inputs): 434 4040
# In for ix, in_ in enumerate(inputs): 435 4040
# In for ix, in_ in enumerate(inputs): 436 4040
# In for ix, in_ in enumerate(inputs): 437 4040
# In for ix, in_ in enumerate(inputs): 438 4040
# In for ix, in_ in enumerate(inputs): 439 4040
# In for ix, in_ in enumerate(inputs): 440 4040
# In for ix, in_ in enumerate(inputs): 441 4040
# In for ix, in_ in enumerate(inputs): 442 4040
# In for ix, in_ in enumerate(inputs): 443 4040
# In for ix, in_ in enumerate(inputs): 444 4040
# In for ix, in_ in enumerate(inputs): 445 4040
# In for ix, in_ in enumerate(inputs): 446 4040
# In for ix, in_ in enumerate(inputs): 447 4040
# In for ix, in_ in enumerate(inputs): 448 4040
# In for ix, in_ in enumerate(inputs): 449 4040
# In for ix, in_ in enumerate(inputs): 450 4040
# In for ix, in_ in enumerate(inputs): 451 4040
# In for ix, in_ in enumerate(inputs): 452 4040
# In for ix, in_ in enumerate(inputs): 453 4040
# In for ix, in_ in enumerate(inputs): 454 4040
# In for ix, in_ in enumerate(inputs): 455 4040
# In for ix, in_ in enumerate(inputs): 456 4040
# In for ix, in_ in enumerate(inputs): 457 4040
# In for ix, in_ in enumerate(inputs): 458 4040
# In for ix, in_ in enumerate(inputs): 459 4040
# In for ix, in_ in enumerate(inputs): 460 4040
# In for ix, in_ in enumerate(inputs): 461 4040
# In for ix, in_ in enumerate(inputs): 462 4040
# In for ix, in_ in enumerate(inputs): 463 4040
# In for ix, in_ in enumerate(inputs): 464 4040
# In for ix, in_ in enumerate(inputs): 465 4040
# In for ix, in_ in enumerate(inputs): 466 4040
# In for ix, in_ in enumerate(inputs): 467 4040
# In for ix, in_ in enumerate(inputs): 468 4040
# In for ix, in_ in enumerate(inputs): 469 4040
# In for ix, in_ in enumerate(inputs): 470 4040
# In for ix, in_ in enumerate(inputs): 471 4040
# In for ix, in_ in enumerate(inputs): 472 4040
# In for ix, in_ in enumerate(inputs): 473 4040
# In for ix, in_ in enumerate(inputs): 474 4040
# In for ix, in_ in enumerate(inputs): 475 4040
# In for ix, in_ in enumerate(inputs): 476 4040
# In for ix, in_ in enumerate(inputs): 477 4040
# In for ix, in_ in enumerate(inputs): 478 4040
# In for ix, in_ in enumerate(inputs): 479 4040
# In for ix, in_ in enumerate(inputs): 480 4040
# In for ix, in_ in enumerate(inputs): 481 4040
# In for ix, in_ in enumerate(inputs): 482 4040
# In for ix, in_ in enumerate(inputs): 483 4040
# In for ix, in_ in enumerate(inputs): 484 4040
# In for ix, in_ in enumerate(inputs): 485 4040
# In for ix, in_ in enumerate(inputs): 486 4040
# In for ix, in_ in enumerate(inputs): 487 4040
# In for ix, in_ in enumerate(inputs): 488 4040
# In for ix, in_ in enumerate(inputs): 489 4040
# In for ix, in_ in enumerate(inputs): 490 4040
# In for ix, in_ in enumerate(inputs): 491 4040
# In for ix, in_ in enumerate(inputs): 492 4040
# In for ix, in_ in enumerate(inputs): 493 4040
# In for ix, in_ in enumerate(inputs): 494 4040
# In for ix, in_ in enumerate(inputs): 495 4040
# In for ix, in_ in enumerate(inputs): 496 4040
# In for ix, in_ in enumerate(inputs): 497 4040
# In for ix, in_ in enumerate(inputs): 498 4040
# In for ix, in_ in enumerate(inputs): 499 4040
# In for ix, in_ in enumerate(inputs): 500 4040
# In for ix, in_ in enumerate(inputs): 501 4040
# In for ix, in_ in enumerate(inputs): 502 4040
# In for ix, in_ in enumerate(inputs): 503 4040
# In for ix, in_ in enumerate(inputs): 504 4040
# In for ix, in_ in enumerate(inputs): 505 4040
# In for ix, in_ in enumerate(inputs): 506 4040
# In for ix, in_ in enumerate(inputs): 507 4040
# In for ix, in_ in enumerate(inputs): 508 4040
# In for ix, in_ in enumerate(inputs): 509 4040
# In for ix, in_ in enumerate(inputs): 510 4040
# In for ix, in_ in enumerate(inputs): 511 4040
# In for ix, in_ in enumerate(inputs): 512 4040
# In for ix, in_ in enumerate(inputs): 513 4040
# In for ix, in_ in enumerate(inputs): 514 4040
# In for ix, in_ in enumerate(inputs): 515 4040
# In for ix, in_ in enumerate(inputs): 516 4040
# In for ix, in_ in enumerate(inputs): 517 4040
# In for ix, in_ in enumerate(inputs): 518 4040
# In for ix, in_ in enumerate(inputs): 519 4040
# In for ix, in_ in enumerate(inputs): 520 4040
# In for ix, in_ in enumerate(inputs): 521 4040
# In for ix, in_ in enumerate(inputs): 522 4040
# In for ix, in_ in enumerate(inputs): 523 4040
# In for ix, in_ in enumerate(inputs): 524 4040
# In for ix, in_ in enumerate(inputs): 525 4040
# In for ix, in_ in enumerate(inputs): 526 4040
# In for ix, in_ in enumerate(inputs): 527 4040
# In for ix, in_ in enumerate(inputs): 528 4040
# In for ix, in_ in enumerate(inputs): 529 4040
# In for ix, in_ in enumerate(inputs): 530 4040
# In for ix, in_ in enumerate(inputs): 531 4040
# In for ix, in_ in enumerate(inputs): 532 4040
# In for ix, in_ in enumerate(inputs): 533 4040
# In for ix, in_ in enumerate(inputs): 534 4040
# In for ix, in_ in enumerate(inputs): 535 4040
# In for ix, in_ in enumerate(inputs): 536 4040
# In for ix, in_ in enumerate(inputs): 537 4040
# In for ix, in_ in enumerate(inputs): 538 4040
# In for ix, in_ in enumerate(inputs): 539 4040
# In for ix, in_ in enumerate(inputs): 540 4040
# In for ix, in_ in enumerate(inputs): 541 4040
# In for ix, in_ in enumerate(inputs): 542 4040
# In for ix, in_ in enumerate(inputs): 543 4040
# In for ix, in_ in enumerate(inputs): 544 4040
# In for ix, in_ in enumerate(inputs): 545 4040
# In for ix, in_ in enumerate(inputs): 546 4040
# In for ix, in_ in enumerate(inputs): 547 4040
# In for ix, in_ in enumerate(inputs): 548 4040
# In for ix, in_ in enumerate(inputs): 549 4040
# In for ix, in_ in enumerate(inputs): 550 4040
# In for ix, in_ in enumerate(inputs): 551 4040
# In for ix, in_ in enumerate(inputs): 552 4040
# In for ix, in_ in enumerate(inputs): 553 4040
# In for ix, in_ in enumerate(inputs): 554 4040
# In for ix, in_ in enumerate(inputs): 555 4040
# In for ix, in_ in enumerate(inputs): 556 4040
# In for ix, in_ in enumerate(inputs): 557 4040
# In for ix, in_ in enumerate(inputs): 558 4040
# In for ix, in_ in enumerate(inputs): 559 4040
# In for ix, in_ in enumerate(inputs): 560 4040
# In for ix, in_ in enumerate(inputs): 561 4040
# In for ix, in_ in enumerate(inputs): 562 4040
# In for ix, in_ in enumerate(inputs): 563 4040
# In for ix, in_ in enumerate(inputs): 564 4040
# In for ix, in_ in enumerate(inputs): 565 4040
# In for ix, in_ in enumerate(inputs): 566 4040
# In for ix, in_ in enumerate(inputs): 567 4040
# In for ix, in_ in enumerate(inputs): 568 4040
# In for ix, in_ in enumerate(inputs): 569 4040
# In for ix, in_ in enumerate(inputs): 570 4040
# In for ix, in_ in enumerate(inputs): 571 4040
# In for ix, in_ in enumerate(inputs): 572 4040
# In for ix, in_ in enumerate(inputs): 573 4040
# In for ix, in_ in enumerate(inputs): 574 4040
# In for ix, in_ in enumerate(inputs): 575 4040
# In for ix, in_ in enumerate(inputs): 576 4040
# In for ix, in_ in enumerate(inputs): 577 4040
# In for ix, in_ in enumerate(inputs): 578 4040
# In for ix, in_ in enumerate(inputs): 579 4040
# In for ix, in_ in enumerate(inputs): 580 4040
# In for ix, in_ in enumerate(inputs): 581 4040
# In for ix, in_ in enumerate(inputs): 582 4040
# In for ix, in_ in enumerate(inputs): 583 4040
# In for ix, in_ in enumerate(inputs): 584 4040
# In for ix, in_ in enumerate(inputs): 585 4040
# In for ix, in_ in enumerate(inputs): 586 4040
# In for ix, in_ in enumerate(inputs): 587 4040
# In for ix, in_ in enumerate(inputs): 588 4040
# In for ix, in_ in enumerate(inputs): 589 4040
# In for ix, in_ in enumerate(inputs): 590 4040
# In for ix, in_ in enumerate(inputs): 591 4040
# In for ix, in_ in enumerate(inputs): 592 4040
# In for ix, in_ in enumerate(inputs): 593 4040
# In for ix, in_ in enumerate(inputs): 594 4040
# In for ix, in_ in enumerate(inputs): 595 4040
# In for ix, in_ in enumerate(inputs): 596 4040
# In for ix, in_ in enumerate(inputs): 597 4040
# In for ix, in_ in enumerate(inputs): 598 4040
# In for ix, in_ in enumerate(inputs): 599 4040
# In for ix, in_ in enumerate(inputs): 600 4040
# In for ix, in_ in enumerate(inputs): 601 4040
# In for ix, in_ in enumerate(inputs): 602 4040
# In for ix, in_ in enumerate(inputs): 603 4040
# In for ix, in_ in enumerate(inputs): 604 4040
# In for ix, in_ in enumerate(inputs): 605 4040
# In for ix, in_ in enumerate(inputs): 606 4040
# In for ix, in_ in enumerate(inputs): 607 4040
# In for ix, in_ in enumerate(inputs): 608 4040
# In for ix, in_ in enumerate(inputs): 609 4040
# In for ix, in_ in enumerate(inputs): 610 4040
# In for ix, in_ in enumerate(inputs): 611 4040
# In for ix, in_ in enumerate(inputs): 612 4040
# In for ix, in_ in enumerate(inputs): 613 4040
# In for ix, in_ in enumerate(inputs): 614 4040
# In for ix, in_ in enumerate(inputs): 615 4040
# In for ix, in_ in enumerate(inputs): 616 4040
# In for ix, in_ in enumerate(inputs): 617 4040
# In for ix, in_ in enumerate(inputs): 618 4040
# In for ix, in_ in enumerate(inputs): 619 4040
# In for ix, in_ in enumerate(inputs): 620 4040
# In for ix, in_ in enumerate(inputs): 621 4040
# In for ix, in_ in enumerate(inputs): 622 4040
# In for ix, in_ in enumerate(inputs): 623 4040
# In for ix, in_ in enumerate(inputs): 624 4040
# In for ix, in_ in enumerate(inputs): 625 4040
# In for ix, in_ in enumerate(inputs): 626 4040
# In for ix, in_ in enumerate(inputs): 627 4040
# In for ix, in_ in enumerate(inputs): 628 4040
# In for ix, in_ in enumerate(inputs): 629 4040
# In for ix, in_ in enumerate(inputs): 630 4040
# In for ix, in_ in enumerate(inputs): 631 4040
# In for ix, in_ in enumerate(inputs): 632 4040
# In for ix, in_ in enumerate(inputs): 633 4040
# In for ix, in_ in enumerate(inputs): 634 4040
# In for ix, in_ in enumerate(inputs): 635 4040
# In for ix, in_ in enumerate(inputs): 636 4040
# In for ix, in_ in enumerate(inputs): 637 4040
# In for ix, in_ in enumerate(inputs): 638 4040
# In for ix, in_ in enumerate(inputs): 639 4040
# In for ix, in_ in enumerate(inputs): 640 4040
# In for ix, in_ in enumerate(inputs): 641 4040
# In for ix, in_ in enumerate(inputs): 642 4040
# In for ix, in_ in enumerate(inputs): 643 4040
# In for ix, in_ in enumerate(inputs): 644 4040
# In for ix, in_ in enumerate(inputs): 645 4040
# In for ix, in_ in enumerate(inputs): 646 4040
# In for ix, in_ in enumerate(inputs): 647 4040
# In for ix, in_ in enumerate(inputs): 648 4040
# In for ix, in_ in enumerate(inputs): 649 4040
# In for ix, in_ in enumerate(inputs): 650 4040
# In for ix, in_ in enumerate(inputs): 651 4040
# In for ix, in_ in enumerate(inputs): 652 4040
# In for ix, in_ in enumerate(inputs): 653 4040
# In for ix, in_ in enumerate(inputs): 654 4040
# In for ix, in_ in enumerate(inputs): 655 4040
# In for ix, in_ in enumerate(inputs): 656 4040
# In for ix, in_ in enumerate(inputs): 657 4040
# In for ix, in_ in enumerate(inputs): 658 4040
# In for ix, in_ in enumerate(inputs): 659 4040
# In for ix, in_ in enumerate(inputs): 660 4040
# In for ix, in_ in enumerate(inputs): 661 4040
# In for ix, in_ in enumerate(inputs): 662 4040
# In for ix, in_ in enumerate(inputs): 663 4040
# In for ix, in_ in enumerate(inputs): 664 4040
# In for ix, in_ in enumerate(inputs): 665 4040
# In for ix, in_ in enumerate(inputs): 666 4040
# In for ix, in_ in enumerate(inputs): 667 4040
# In for ix, in_ in enumerate(inputs): 668 4040
# In for ix, in_ in enumerate(inputs): 669 4040
# In for ix, in_ in enumerate(inputs): 670 4040
# In for ix, in_ in enumerate(inputs): 671 4040
# In for ix, in_ in enumerate(inputs): 672 4040
# In for ix, in_ in enumerate(inputs): 673 4040
# In for ix, in_ in enumerate(inputs): 674 4040
# In for ix, in_ in enumerate(inputs): 675 4040
# In for ix, in_ in enumerate(inputs): 676 4040
# In for ix, in_ in enumerate(inputs): 677 4040
# In for ix, in_ in enumerate(inputs): 678 4040
# In for ix, in_ in enumerate(inputs): 679 4040
# In for ix, in_ in enumerate(inputs): 680 4040
# In for ix, in_ in enumerate(inputs): 681 4040
# In for ix, in_ in enumerate(inputs): 682 4040
# In for ix, in_ in enumerate(inputs): 683 4040
# In for ix, in_ in enumerate(inputs): 684 4040
# In for ix, in_ in enumerate(inputs): 685 4040
# In for ix, in_ in enumerate(inputs): 686 4040
# In for ix, in_ in enumerate(inputs): 687 4040
# In for ix, in_ in enumerate(inputs): 688 4040
# In for ix, in_ in enumerate(inputs): 689 4040
# In for ix, in_ in enumerate(inputs): 690 4040
# In for ix, in_ in enumerate(inputs): 691 4040
# In for ix, in_ in enumerate(inputs): 692 4040
# In for ix, in_ in enumerate(inputs): 693 4040
# In for ix, in_ in enumerate(inputs): 694 4040
# In for ix, in_ in enumerate(inputs): 695 4040
# In for ix, in_ in enumerate(inputs): 696 4040
# In for ix, in_ in enumerate(inputs): 697 4040
# In for ix, in_ in enumerate(inputs): 698 4040
# In for ix, in_ in enumerate(inputs): 699 4040
# In for ix, in_ in enumerate(inputs): 700 4040
# In for ix, in_ in enumerate(inputs): 701 4040
# In for ix, in_ in enumerate(inputs): 702 4040
# In for ix, in_ in enumerate(inputs): 703 4040
# In for ix, in_ in enumerate(inputs): 704 4040
# In for ix, in_ in enumerate(inputs): 705 4040
# In for ix, in_ in enumerate(inputs): 706 4040
# In for ix, in_ in enumerate(inputs): 707 4040
# In for ix, in_ in enumerate(inputs): 708 4040
# In for ix, in_ in enumerate(inputs): 709 4040
# In for ix, in_ in enumerate(inputs): 710 4040
# In for ix, in_ in enumerate(inputs): 711 4040
# In for ix, in_ in enumerate(inputs): 712 4040
# In for ix, in_ in enumerate(inputs): 713 4040
# In for ix, in_ in enumerate(inputs): 714 4040
# In for ix, in_ in enumerate(inputs): 715 4040
# In for ix, in_ in enumerate(inputs): 716 4040
# In for ix, in_ in enumerate(inputs): 717 4040
# In for ix, in_ in enumerate(inputs): 718 4040
# In for ix, in_ in enumerate(inputs): 719 4040
# In for ix, in_ in enumerate(inputs): 720 4040
# In for ix, in_ in enumerate(inputs): 721 4040
# In for ix, in_ in enumerate(inputs): 722 4040
# In for ix, in_ in enumerate(inputs): 723 4040
# In for ix, in_ in enumerate(inputs): 724 4040
# In for ix, in_ in enumerate(inputs): 725 4040
# In for ix, in_ in enumerate(inputs): 726 4040
# In for ix, in_ in enumerate(inputs): 727 4040
# In for ix, in_ in enumerate(inputs): 728 4040
# In for ix, in_ in enumerate(inputs): 729 4040
# In for ix, in_ in enumerate(inputs): 730 4040
# In for ix, in_ in enumerate(inputs): 731 4040
# In for ix, in_ in enumerate(inputs): 732 4040
# In for ix, in_ in enumerate(inputs): 733 4040
# In for ix, in_ in enumerate(inputs): 734 4040
# In for ix, in_ in enumerate(inputs): 735 4040
# In for ix, in_ in enumerate(inputs): 736 4040
# In for ix, in_ in enumerate(inputs): 737 4040
# In for ix, in_ in enumerate(inputs): 738 4040
# In for ix, in_ in enumerate(inputs): 739 4040
# In for ix, in_ in enumerate(inputs): 740 4040
# In for ix, in_ in enumerate(inputs): 741 4040
# In for ix, in_ in enumerate(inputs): 742 4040
# In for ix, in_ in enumerate(inputs): 743 4040
# In for ix, in_ in enumerate(inputs): 744 4040
# In for ix, in_ in enumerate(inputs): 745 4040
# In for ix, in_ in enumerate(inputs): 746 4040
# In for ix, in_ in enumerate(inputs): 747 4040
# In for ix, in_ in enumerate(inputs): 748 4040
# In for ix, in_ in enumerate(inputs): 749 4040
# In for ix, in_ in enumerate(inputs): 750 4040
# In for ix, in_ in enumerate(inputs): 751 4040
# In for ix, in_ in enumerate(inputs): 752 4040
# In for ix, in_ in enumerate(inputs): 753 4040
# In for ix, in_ in enumerate(inputs): 754 4040
# In for ix, in_ in enumerate(inputs): 755 4040
# In for ix, in_ in enumerate(inputs): 756 4040
# In for ix, in_ in enumerate(inputs): 757 4040
# In for ix, in_ in enumerate(inputs): 758 4040
# In for ix, in_ in enumerate(inputs): 759 4040
# In for ix, in_ in enumerate(inputs): 760 4040
# In for ix, in_ in enumerate(inputs): 761 4040
# In for ix, in_ in enumerate(inputs): 762 4040
# In for ix, in_ in enumerate(inputs): 763 4040
# In for ix, in_ in enumerate(inputs): 764 4040
# In for ix, in_ in enumerate(inputs): 765 4040
# In for ix, in_ in enumerate(inputs): 766 4040
# In for ix, in_ in enumerate(inputs): 767 4040
# In for ix, in_ in enumerate(inputs): 768 4040
# In for ix, in_ in enumerate(inputs): 769 4040
# In for ix, in_ in enumerate(inputs): 770 4040
# In for ix, in_ in enumerate(inputs): 771 4040
# In for ix, in_ in enumerate(inputs): 772 4040
# In for ix, in_ in enumerate(inputs): 773 4040
# In for ix, in_ in enumerate(inputs): 774 4040
# In for ix, in_ in enumerate(inputs): 775 4040
# In for ix, in_ in enumerate(inputs): 776 4040
# In for ix, in_ in enumerate(inputs): 777 4040
# In for ix, in_ in enumerate(inputs): 778 4040
# In for ix, in_ in enumerate(inputs): 779 4040
# In for ix, in_ in enumerate(inputs): 780 4040
# In for ix, in_ in enumerate(inputs): 781 4040
# In for ix, in_ in enumerate(inputs): 782 4040
# In for ix, in_ in enumerate(inputs): 783 4040
# In for ix, in_ in enumerate(inputs): 784 4040
# In for ix, in_ in enumerate(inputs): 785 4040
# In for ix, in_ in enumerate(inputs): 786 4040
# In for ix, in_ in enumerate(inputs): 787 4040
# In for ix, in_ in enumerate(inputs): 788 4040
# In for ix, in_ in enumerate(inputs): 789 4040
# In for ix, in_ in enumerate(inputs): 790 4040
# In for ix, in_ in enumerate(inputs): 791 4040
# In for ix, in_ in enumerate(inputs): 792 4040
# In for ix, in_ in enumerate(inputs): 793 4040
# In for ix, in_ in enumerate(inputs): 794 4040
# In for ix, in_ in enumerate(inputs): 795 4040
# In for ix, in_ in enumerate(inputs): 796 4040
# In for ix, in_ in enumerate(inputs): 797 4040
# In for ix, in_ in enumerate(inputs): 798 4040
# In for ix, in_ in enumerate(inputs): 799 4040
# In for ix, in_ in enumerate(inputs): 800 4040
# In for ix, in_ in enumerate(inputs): 801 4040
# In for ix, in_ in enumerate(inputs): 802 4040
# In for ix, in_ in enumerate(inputs): 803 4040
# In for ix, in_ in enumerate(inputs): 804 4040
# In for ix, in_ in enumerate(inputs): 805 4040
# In for ix, in_ in enumerate(inputs): 806 4040
# In for ix, in_ in enumerate(inputs): 807 4040
# In for ix, in_ in enumerate(inputs): 808 4040
# In for ix, in_ in enumerate(inputs): 809 4040
# In for ix, in_ in enumerate(inputs): 810 4040
# In for ix, in_ in enumerate(inputs): 811 4040
# In for ix, in_ in enumerate(inputs): 812 4040
# In for ix, in_ in enumerate(inputs): 813 4040
# In for ix, in_ in enumerate(inputs): 814 4040
# In for ix, in_ in enumerate(inputs): 815 4040
# In for ix, in_ in enumerate(inputs): 816 4040
# In for ix, in_ in enumerate(inputs): 817 4040
# In for ix, in_ in enumerate(inputs): 818 4040
# In for ix, in_ in enumerate(inputs): 819 4040
# In for ix, in_ in enumerate(inputs): 820 4040
# In for ix, in_ in enumerate(inputs): 821 4040
# In for ix, in_ in enumerate(inputs): 822 4040
# In for ix, in_ in enumerate(inputs): 823 4040
# In for ix, in_ in enumerate(inputs): 824 4040
# In for ix, in_ in enumerate(inputs): 825 4040
# In for ix, in_ in enumerate(inputs): 826 4040
# In for ix, in_ in enumerate(inputs): 827 4040
# In for ix, in_ in enumerate(inputs): 828 4040
# In for ix, in_ in enumerate(inputs): 829 4040
# In for ix, in_ in enumerate(inputs): 830 4040
# In for ix, in_ in enumerate(inputs): 831 4040
# In for ix, in_ in enumerate(inputs): 832 4040
# In for ix, in_ in enumerate(inputs): 833 4040
# In for ix, in_ in enumerate(inputs): 834 4040
# In for ix, in_ in enumerate(inputs): 835 4040
# In for ix, in_ in enumerate(inputs): 836 4040
# In for ix, in_ in enumerate(inputs): 837 4040
# In for ix, in_ in enumerate(inputs): 838 4040
# In for ix, in_ in enumerate(inputs): 839 4040
# In for ix, in_ in enumerate(inputs): 840 4040
# In for ix, in_ in enumerate(inputs): 841 4040
# In for ix, in_ in enumerate(inputs): 842 4040
# In for ix, in_ in enumerate(inputs): 843 4040
# In for ix, in_ in enumerate(inputs): 844 4040
# In for ix, in_ in enumerate(inputs): 845 4040
# In for ix, in_ in enumerate(inputs): 846 4040
# In for ix, in_ in enumerate(inputs): 847 4040
# In for ix, in_ in enumerate(inputs): 848 4040
# In for ix, in_ in enumerate(inputs): 849 4040
# In for ix, in_ in enumerate(inputs): 850 4040
# In for ix, in_ in enumerate(inputs): 851 4040
# In for ix, in_ in enumerate(inputs): 852 4040
# In for ix, in_ in enumerate(inputs): 853 4040
# In for ix, in_ in enumerate(inputs): 854 4040
# In for ix, in_ in enumerate(inputs): 855 4040
# In for ix, in_ in enumerate(inputs): 856 4040
# In for ix, in_ in enumerate(inputs): 857 4040
# In for ix, in_ in enumerate(inputs): 858 4040
# In for ix, in_ in enumerate(inputs): 859 4040
# In for ix, in_ in enumerate(inputs): 860 4040
# In for ix, in_ in enumerate(inputs): 861 4040
# In for ix, in_ in enumerate(inputs): 862 4040
# In for ix, in_ in enumerate(inputs): 863 4040
# In for ix, in_ in enumerate(inputs): 864 4040
# In for ix, in_ in enumerate(inputs): 865 4040
# In for ix, in_ in enumerate(inputs): 866 4040
# In for ix, in_ in enumerate(inputs): 867 4040
# In for ix, in_ in enumerate(inputs): 868 4040
# In for ix, in_ in enumerate(inputs): 869 4040
# In for ix, in_ in enumerate(inputs): 870 4040
# In for ix, in_ in enumerate(inputs): 871 4040
# In for ix, in_ in enumerate(inputs): 872 4040
# In for ix, in_ in enumerate(inputs): 873 4040
# In for ix, in_ in enumerate(inputs): 874 4040
# In for ix, in_ in enumerate(inputs): 875 4040
# In for ix, in_ in enumerate(inputs): 876 4040
# In for ix, in_ in enumerate(inputs): 877 4040
# In for ix, in_ in enumerate(inputs): 878 4040
# In for ix, in_ in enumerate(inputs): 879 4040
# In for ix, in_ in enumerate(inputs): 880 4040
# In for ix, in_ in enumerate(inputs): 881 4040
# In for ix, in_ in enumerate(inputs): 882 4040
# In for ix, in_ in enumerate(inputs): 883 4040
# In for ix, in_ in enumerate(inputs): 884 4040
# In for ix, in_ in enumerate(inputs): 885 4040
# In for ix, in_ in enumerate(inputs): 886 4040
# In for ix, in_ in enumerate(inputs): 887 4040
# In for ix, in_ in enumerate(inputs): 888 4040
# In for ix, in_ in enumerate(inputs): 889 4040
# In for ix, in_ in enumerate(inputs): 890 4040
# In for ix, in_ in enumerate(inputs): 891 4040
# In for ix, in_ in enumerate(inputs): 892 4040
# In for ix, in_ in enumerate(inputs): 893 4040
# In for ix, in_ in enumerate(inputs): 894 4040
# In for ix, in_ in enumerate(inputs): 895 4040
# In for ix, in_ in enumerate(inputs): 896 4040
# In for ix, in_ in enumerate(inputs): 897 4040
# In for ix, in_ in enumerate(inputs): 898 4040
# In for ix, in_ in enumerate(inputs): 899 4040
# In for ix, in_ in enumerate(inputs): 900 4040
# In for ix, in_ in enumerate(inputs): 901 4040
# In for ix, in_ in enumerate(inputs): 902 4040
# In for ix, in_ in enumerate(inputs): 903 4040
# In for ix, in_ in enumerate(inputs): 904 4040
# In for ix, in_ in enumerate(inputs): 905 4040
# In for ix, in_ in enumerate(inputs): 906 4040
# In for ix, in_ in enumerate(inputs): 907 4040
# In for ix, in_ in enumerate(inputs): 908 4040
# In for ix, in_ in enumerate(inputs): 909 4040
# In for ix, in_ in enumerate(inputs): 910 4040
# In for ix, in_ in enumerate(inputs): 911 4040
# In for ix, in_ in enumerate(inputs): 912 4040
# In for ix, in_ in enumerate(inputs): 913 4040
# In for ix, in_ in enumerate(inputs): 914 4040
# In for ix, in_ in enumerate(inputs): 915 4040
# In for ix, in_ in enumerate(inputs): 916 4040
# In for ix, in_ in enumerate(inputs): 917 4040
# In for ix, in_ in enumerate(inputs): 918 4040
# In for ix, in_ in enumerate(inputs): 919 4040
# In for ix, in_ in enumerate(inputs): 920 4040
# In for ix, in_ in enumerate(inputs): 921 4040
# In for ix, in_ in enumerate(inputs): 922 4040
# In for ix, in_ in enumerate(inputs): 923 4040
# In for ix, in_ in enumerate(inputs): 924 4040
# In for ix, in_ in enumerate(inputs): 925 4040
# In for ix, in_ in enumerate(inputs): 926 4040
# In for ix, in_ in enumerate(inputs): 927 4040
# In for ix, in_ in enumerate(inputs): 928 4040
# In for ix, in_ in enumerate(inputs): 929 4040
# In for ix, in_ in enumerate(inputs): 930 4040
# In for ix, in_ in enumerate(inputs): 931 4040
# In for ix, in_ in enumerate(inputs): 932 4040
# In for ix, in_ in enumerate(inputs): 933 4040
# In for ix, in_ in enumerate(inputs): 934 4040
# In for ix, in_ in enumerate(inputs): 935 4040
# In for ix, in_ in enumerate(inputs): 936 4040
# In for ix, in_ in enumerate(inputs): 937 4040
# In for ix, in_ in enumerate(inputs): 938 4040
# In for ix, in_ in enumerate(inputs): 939 4040
# In for ix, in_ in enumerate(inputs): 940 4040
# In for ix, in_ in enumerate(inputs): 941 4040
# In for ix, in_ in enumerate(inputs): 942 4040
# In for ix, in_ in enumerate(inputs): 943 4040
# In for ix, in_ in enumerate(inputs): 944 4040
# In for ix, in_ in enumerate(inputs): 945 4040
# In for ix, in_ in enumerate(inputs): 946 4040
# In for ix, in_ in enumerate(inputs): 947 4040
# In for ix, in_ in enumerate(inputs): 948 4040
# In for ix, in_ in enumerate(inputs): 949 4040
# In for ix, in_ in enumerate(inputs): 950 4040
# In for ix, in_ in enumerate(inputs): 951 4040
# In for ix, in_ in enumerate(inputs): 952 4040
# In for ix, in_ in enumerate(inputs): 953 4040
# In for ix, in_ in enumerate(inputs): 954 4040
# In for ix, in_ in enumerate(inputs): 955 4040
# In for ix, in_ in enumerate(inputs): 956 4040
# In for ix, in_ in enumerate(inputs): 957 4040
# In for ix, in_ in enumerate(inputs): 958 4040
# In for ix, in_ in enumerate(inputs): 959 4040
# In for ix, in_ in enumerate(inputs): 960 4040
# In for ix, in_ in enumerate(inputs): 961 4040
# In for ix, in_ in enumerate(inputs): 962 4040
# In for ix, in_ in enumerate(inputs): 963 4040
# In for ix, in_ in enumerate(inputs): 964 4040
# In for ix, in_ in enumerate(inputs): 965 4040
# In for ix, in_ in enumerate(inputs): 966 4040
# In for ix, in_ in enumerate(inputs): 967 4040
# In for ix, in_ in enumerate(inputs): 968 4040
# In for ix, in_ in enumerate(inputs): 969 4040
# In for ix, in_ in enumerate(inputs): 970 4040
# In for ix, in_ in enumerate(inputs): 971 4040
# In for ix, in_ in enumerate(inputs): 972 4040
# In for ix, in_ in enumerate(inputs): 973 4040
# In for ix, in_ in enumerate(inputs): 974 4040
# In for ix, in_ in enumerate(inputs): 975 4040
# In for ix, in_ in enumerate(inputs): 976 4040
# In for ix, in_ in enumerate(inputs): 977 4040
# In for ix, in_ in enumerate(inputs): 978 4040
# In for ix, in_ in enumerate(inputs): 979 4040
# In for ix, in_ in enumerate(inputs): 980 4040
# In for ix, in_ in enumerate(inputs): 981 4040
# In for ix, in_ in enumerate(inputs): 982 4040
# In for ix, in_ in enumerate(inputs): 983 4040
# In for ix, in_ in enumerate(inputs): 984 4040
# In for ix, in_ in enumerate(inputs): 985 4040
# In for ix, in_ in enumerate(inputs): 986 4040
# In for ix, in_ in enumerate(inputs): 987 4040
# In for ix, in_ in enumerate(inputs): 988 4040
# In for ix, in_ in enumerate(inputs): 989 4040
# In for ix, in_ in enumerate(inputs): 990 4040
# In for ix, in_ in enumerate(inputs): 991 4040
# In for ix, in_ in enumerate(inputs): 992 4040
# In for ix, in_ in enumerate(inputs): 993 4040
# In for ix, in_ in enumerate(inputs): 994 4040
# In for ix, in_ in enumerate(inputs): 995 4040
# In for ix, in_ in enumerate(inputs): 996 4040
# In for ix, in_ in enumerate(inputs): 997 4040
# In for ix, in_ in enumerate(inputs): 998 4040
# In for ix, in_ in enumerate(inputs): 999 4040
# In for ix, in_ in enumerate(inputs): 1000 4040
# In for ix, in_ in enumerate(inputs): 1001 4040
# In for ix, in_ in enumerate(inputs): 1002 4040
# In for ix, in_ in enumerate(inputs): 1003 4040
# In for ix, in_ in enumerate(inputs): 1004 4040
# In for ix, in_ in enumerate(inputs): 1005 4040
# In for ix, in_ in enumerate(inputs): 1006 4040
# In for ix, in_ in enumerate(inputs): 1007 4040
# In for ix, in_ in enumerate(inputs): 1008 4040
# In for ix, in_ in enumerate(inputs): 1009 4040
# In for ix, in_ in enumerate(inputs): 1010 4040
# In for ix, in_ in enumerate(inputs): 1011 4040
# In for ix, in_ in enumerate(inputs): 1012 4040
# In for ix, in_ in enumerate(inputs): 1013 4040
# In for ix, in_ in enumerate(inputs): 1014 4040
# In for ix, in_ in enumerate(inputs): 1015 4040
# In for ix, in_ in enumerate(inputs): 1016 4040
# In for ix, in_ in enumerate(inputs): 1017 4040
# In for ix, in_ in enumerate(inputs): 1018 4040
# In for ix, in_ in enumerate(inputs): 1019 4040
# In for ix, in_ in enumerate(inputs): 1020 4040
# In for ix, in_ in enumerate(inputs): 1021 4040
# In for ix, in_ in enumerate(inputs): 1022 4040
# In for ix, in_ in enumerate(inputs): 1023 4040
# In for ix, in_ in enumerate(inputs): 1024 4040
# In for ix, in_ in enumerate(inputs): 1025 4040
# In for ix, in_ in enumerate(inputs): 1026 4040
# In for ix, in_ in enumerate(inputs): 1027 4040
# In for ix, in_ in enumerate(inputs): 1028 4040
# In for ix, in_ in enumerate(inputs): 1029 4040
# In for ix, in_ in enumerate(inputs): 1030 4040
# In for ix, in_ in enumerate(inputs): 1031 4040
# In for ix, in_ in enumerate(inputs): 1032 4040
# In for ix, in_ in enumerate(inputs): 1033 4040
# In for ix, in_ in enumerate(inputs): 1034 4040
# In for ix, in_ in enumerate(inputs): 1035 4040
# In for ix, in_ in enumerate(inputs): 1036 4040
# In for ix, in_ in enumerate(inputs): 1037 4040
# In for ix, in_ in enumerate(inputs): 1038 4040
# In for ix, in_ in enumerate(inputs): 1039 4040
# In for ix, in_ in enumerate(inputs): 1040 4040
# In for ix, in_ in enumerate(inputs): 1041 4040
# In for ix, in_ in enumerate(inputs): 1042 4040
# In for ix, in_ in enumerate(inputs): 1043 4040
# ...
# In for ix, in_ in enumerate(inputs): 3708 4040
# In for ix, in_ in enumerate(inputs): 3709 4040
# In for ix, in_ in enumerate(inputs): 3710 4040
# In for ix, in_ in enumerate(inputs): 3711 4040
# In for ix, in_ in enumerate(inputs): 3712 4040
# In for ix, in_ in enumerate(inputs): 3713 4040
# In for ix, in_ in enumerate(inputs): 3714 4040
# In for ix, in_ in enumerate(inputs): 3715 4040
# In for ix, in_ in enumerate(inputs): 3716 4040
# In for ix, in_ in enumerate(inputs): 3717 4040
# In for ix, in_ in enumerate(inputs): 3718 4040
# In for ix, in_ in enumerate(inputs): 3719 4040
# In for ix, in_ in enumerate(inputs): 3720 4040
# In for ix, in_ in enumerate(inputs): 3721 4040
# In for ix, in_ in enumerate(inputs): 3722 4040
# In for ix, in_ in enumerate(inputs): 3723 4040
# In for ix, in_ in enumerate(inputs): 3724 4040
# In for ix, in_ in enumerate(inputs): 3725 4040
# In for ix, in_ in enumerate(inputs): 3726 4040
# In for ix, in_ in enumerate(inputs): 3727 4040
# In for ix, in_ in enumerate(inputs): 3728 4040
# In for ix, in_ in enumerate(inputs): 3729 4040
# In for ix, in_ in enumerate(inputs): 3730 4040
# In for ix, in_ in enumerate(inputs): 3731 4040
# In for ix, in_ in enumerate(inputs): 3732 4040
# In for ix, in_ in enumerate(inputs): 3733 4040
# In for ix, in_ in enumerate(inputs): 3734 4040
# In for ix, in_ in enumerate(inputs): 3735 4040
# In for ix, in_ in enumerate(inputs): 3736 4040
# In for ix, in_ in enumerate(inputs): 3737 4040
# In for ix, in_ in enumerate(inputs): 3738 4040
# In for ix, in_ in enumerate(inputs): 3739 4040
# In for ix, in_ in enumerate(inputs): 3740 4040
# In for ix, in_ in enumerate(inputs): 3741 4040
# In for ix, in_ in enumerate(inputs): 3742 4040
# In for ix, in_ in enumerate(inputs): 3743 4040
# In for ix, in_ in enumerate(inputs): 3744 4040
# In for ix, in_ in enumerate(inputs): 3745 4040
# In for ix, in_ in enumerate(inputs): 3746 4040
# In for ix, in_ in enumerate(inputs): 3747 4040
# In for ix, in_ in enumerate(inputs): 3748 4040
# In for ix, in_ in enumerate(inputs): 3749 4040
# In for ix, in_ in enumerate(inputs): 3750 4040
# In for ix, in_ in enumerate(inputs): 3751 4040
# In for ix, in_ in enumerate(inputs): 3752 4040
# In for ix, in_ in enumerate(inputs): 3753 4040
# In for ix, in_ in enumerate(inputs): 3754 4040
# In for ix, in_ in enumerate(inputs): 3755 4040
# In for ix, in_ in enumerate(inputs): 3756 4040
# In for ix, in_ in enumerate(inputs): 3757 4040
# In for ix, in_ in enumerate(inputs): 3758 4040
# In for ix, in_ in enumerate(inputs): 3759 4040
# In for ix, in_ in enumerate(inputs): 3760 4040
# In for ix, in_ in enumerate(inputs): 3761 4040
# In for ix, in_ in enumerate(inputs): 3762 4040
# In for ix, in_ in enumerate(inputs): 3763 4040
# In for ix, in_ in enumerate(inputs): 3764 4040
# In for ix, in_ in enumerate(inputs): 3765 4040
# In for ix, in_ in enumerate(inputs): 3766 4040
# In for ix, in_ in enumerate(inputs): 3767 4040
# In for ix, in_ in enumerate(inputs): 3768 4040
# In for ix, in_ in enumerate(inputs): 3769 4040
# In for ix, in_ in enumerate(inputs): 3770 4040
# In for ix, in_ in enumerate(inputs): 3771 4040
# In for ix, in_ in enumerate(inputs): 3772 4040
# In for ix, in_ in enumerate(inputs): 3773 4040
# In for ix, in_ in enumerate(inputs): 3774 4040
# In for ix, in_ in enumerate(inputs): 3775 4040
# In for ix, in_ in enumerate(inputs): 3776 4040
# In for ix, in_ in enumerate(inputs): 3777 4040
# In for ix, in_ in enumerate(inputs): 3778 4040
# In for ix, in_ in enumerate(inputs): 3779 4040
# In for ix, in_ in enumerate(inputs): 3780 4040
# In for ix, in_ in enumerate(inputs): 3781 4040
# In for ix, in_ in enumerate(inputs): 3782 4040
# In for ix, in_ in enumerate(inputs): 3783 4040
# In for ix, in_ in enumerate(inputs): 3784 4040
# In for ix, in_ in enumerate(inputs): 3785 4040
# In for ix, in_ in enumerate(inputs): 3786 4040
# In for ix, in_ in enumerate(inputs): 3787 4040
# In for ix, in_ in enumerate(inputs): 3788 4040
# In for ix, in_ in enumerate(inputs): 3789 4040
# In for ix, in_ in enumerate(inputs): 3790 4040
# In for ix, in_ in enumerate(inputs): 3791 4040
# In for ix, in_ in enumerate(inputs): 3792 4040
# In for ix, in_ in enumerate(inputs): 3793 4040
# In for ix, in_ in enumerate(inputs): 3794 4040
# In for ix, in_ in enumerate(inputs): 3795 4040
# In for ix, in_ in enumerate(inputs): 3796 4040
# In for ix, in_ in enumerate(inputs): 3797 4040
# In for ix, in_ in enumerate(inputs): 3798 4040
# In for ix, in_ in enumerate(inputs): 3799 4040
# In for ix, in_ in enumerate(inputs): 3800 4040
# In for ix, in_ in enumerate(inputs): 3801 4040
# In for ix, in_ in enumerate(inputs): 3802 4040
# In for ix, in_ in enumerate(inputs): 3803 4040
# In for ix, in_ in enumerate(inputs): 3804 4040
# In for ix, in_ in enumerate(inputs): 3805 4040
# In for ix, in_ in enumerate(inputs): 3806 4040
# In for ix, in_ in enumerate(inputs): 3807 4040
# In for ix, in_ in enumerate(inputs): 3808 4040
# In for ix, in_ in enumerate(inputs): 3809 4040
# In for ix, in_ in enumerate(inputs): 3810 4040
# In for ix, in_ in enumerate(inputs): 3811 4040
# In for ix, in_ in enumerate(inputs): 3812 4040
# In for ix, in_ in enumerate(inputs): 3813 4040
# In for ix, in_ in enumerate(inputs): 3814 4040
# In for ix, in_ in enumerate(inputs): 3815 4040
# In for ix, in_ in enumerate(inputs): 3816 4040
# In for ix, in_ in enumerate(inputs): 3817 4040
# In for ix, in_ in enumerate(inputs): 3818 4040
# In for ix, in_ in enumerate(inputs): 3819 4040
# In for ix, in_ in enumerate(inputs): 3820 4040
# In for ix, in_ in enumerate(inputs): 3821 4040
# In for ix, in_ in enumerate(inputs): 3822 4040
# In for ix, in_ in enumerate(inputs): 3823 4040
# In for ix, in_ in enumerate(inputs): 3824 4040
# In for ix, in_ in enumerate(inputs): 3825 4040
# In for ix, in_ in enumerate(inputs): 3826 4040
# In for ix, in_ in enumerate(inputs): 3827 4040
# In for ix, in_ in enumerate(inputs): 3828 4040
# In for ix, in_ in enumerate(inputs): 3829 4040
# In for ix, in_ in enumerate(inputs): 3830 4040
# In for ix, in_ in enumerate(inputs): 3831 4040
# In for ix, in_ in enumerate(inputs): 3832 4040
# In for ix, in_ in enumerate(inputs): 3833 4040
# In for ix, in_ in enumerate(inputs): 3834 4040
# In for ix, in_ in enumerate(inputs): 3835 4040
# In for ix, in_ in enumerate(inputs): 3836 4040
# In for ix, in_ in enumerate(inputs): 3837 4040
# In for ix, in_ in enumerate(inputs): 3838 4040
# In for ix, in_ in enumerate(inputs): 3839 4040
# In for ix, in_ in enumerate(inputs): 3840 4040
# In for ix, in_ in enumerate(inputs): 3841 4040
# In for ix, in_ in enumerate(inputs): 3842 4040
# In for ix, in_ in enumerate(inputs): 3843 4040
# In for ix, in_ in enumerate(inputs): 3844 4040
# In for ix, in_ in enumerate(inputs): 3845 4040
# In for ix, in_ in enumerate(inputs): 3846 4040
# In for ix, in_ in enumerate(inputs): 3847 4040
# In for ix, in_ in enumerate(inputs): 3848 4040
# In for ix, in_ in enumerate(inputs): 3849 4040
# In for ix, in_ in enumerate(inputs): 3850 4040
# In for ix, in_ in enumerate(inputs): 3851 4040
# In for ix, in_ in enumerate(inputs): 3852 4040
# In for ix, in_ in enumerate(inputs): 3853 4040
# In for ix, in_ in enumerate(inputs): 3854 4040
# In for ix, in_ in enumerate(inputs): 3855 4040
# In for ix, in_ in enumerate(inputs): 3856 4040
# In for ix, in_ in enumerate(inputs): 3857 4040
# In for ix, in_ in enumerate(inputs): 3858 4040
# In for ix, in_ in enumerate(inputs): 3859 4040
# In for ix, in_ in enumerate(inputs): 3860 4040
# In for ix, in_ in enumerate(inputs): 3861 4040
# In for ix, in_ in enumerate(inputs): 3862 4040
# In for ix, in_ in enumerate(inputs): 3863 4040
# In for ix, in_ in enumerate(inputs): 3864 4040
# In for ix, in_ in enumerate(inputs): 3865 4040
# In for ix, in_ in enumerate(inputs): 3866 4040
# In for ix, in_ in enumerate(inputs): 3867 4040
# In for ix, in_ in enumerate(inputs): 3868 4040
# In for ix, in_ in enumerate(inputs): 3869 4040
# In for ix, in_ in enumerate(inputs): 3870 4040
# In for ix, in_ in enumerate(inputs): 3871 4040
# In for ix, in_ in enumerate(inputs): 3872 4040
# In for ix, in_ in enumerate(inputs): 3873 4040
# In for ix, in_ in enumerate(inputs): 3874 4040
# In for ix, in_ in enumerate(inputs): 3875 4040
# In for ix, in_ in enumerate(inputs): 3876 4040
# In for ix, in_ in enumerate(inputs): 3877 4040
# In for ix, in_ in enumerate(inputs): 3878 4040
# In for ix, in_ in enumerate(inputs): 3879 4040
# In for ix, in_ in enumerate(inputs): 3880 4040
# In for ix, in_ in enumerate(inputs): 3881 4040
# In for ix, in_ in enumerate(inputs): 3882 4040
# In for ix, in_ in enumerate(inputs): 3883 4040
# In for ix, in_ in enumerate(inputs): 3884 4040
# In for ix, in_ in enumerate(inputs): 3885 4040
# In for ix, in_ in enumerate(inputs): 3886 4040
# In for ix, in_ in enumerate(inputs): 3887 4040
# In for ix, in_ in enumerate(inputs): 3888 4040
# In for ix, in_ in enumerate(inputs): 3889 4040
# In for ix, in_ in enumerate(inputs): 3890 4040
# In for ix, in_ in enumerate(inputs): 3891 4040
# In for ix, in_ in enumerate(inputs): 3892 4040
# In for ix, in_ in enumerate(inputs): 3893 4040
# In for ix, in_ in enumerate(inputs): 3894 4040
# In for ix, in_ in enumerate(inputs): 3895 4040
# In for ix, in_ in enumerate(inputs): 3896 4040
# In for ix, in_ in enumerate(inputs): 3897 4040
# In for ix, in_ in enumerate(inputs): 3898 4040
# In for ix, in_ in enumerate(inputs): 3899 4040
# In for ix, in_ in enumerate(inputs): 3900 4040
# In for ix, in_ in enumerate(inputs): 3901 4040
# In for ix, in_ in enumerate(inputs): 3902 4040
# In for ix, in_ in enumerate(inputs): 3903 4040
# In for ix, in_ in enumerate(inputs): 3904 4040
# In for ix, in_ in enumerate(inputs): 3905 4040
# In for ix, in_ in enumerate(inputs): 3906 4040
# In for ix, in_ in enumerate(inputs): 3907 4040
# In for ix, in_ in enumerate(inputs): 3908 4040
# In for ix, in_ in enumerate(inputs): 3909 4040
# In for ix, in_ in enumerate(inputs): 3910 4040
# In for ix, in_ in enumerate(inputs): 3911 4040
# In for ix, in_ in enumerate(inputs): 3912 4040
# In for ix, in_ in enumerate(inputs): 3913 4040
# In for ix, in_ in enumerate(inputs): 3914 4040
# In for ix, in_ in enumerate(inputs): 3915 4040
# In for ix, in_ in enumerate(inputs): 3916 4040
# In for ix, in_ in enumerate(inputs): 3917 4040
# In for ix, in_ in enumerate(inputs): 3918 4040
# In for ix, in_ in enumerate(inputs): 3919 4040
# In for ix, in_ in enumerate(inputs): 3920 4040
# In for ix, in_ in enumerate(inputs): 3921 4040
# In for ix, in_ in enumerate(inputs): 3922 4040
# In for ix, in_ in enumerate(inputs): 3923 4040
# In for ix, in_ in enumerate(inputs): 3924 4040
# In for ix, in_ in enumerate(inputs): 3925 4040
# In for ix, in_ in enumerate(inputs): 3926 4040
# In for ix, in_ in enumerate(inputs): 3927 4040
# In for ix, in_ in enumerate(inputs): 3928 4040
# In for ix, in_ in enumerate(inputs): 3929 4040
# In for ix, in_ in enumerate(inputs): 3930 4040
# In for ix, in_ in enumerate(inputs): 3931 4040
# In for ix, in_ in enumerate(inputs): 3932 4040
# In for ix, in_ in enumerate(inputs): 3933 4040
# In for ix, in_ in enumerate(inputs): 3934 4040
# In for ix, in_ in enumerate(inputs): 3935 4040
# In for ix, in_ in enumerate(inputs): 3936 4040
# In for ix, in_ in enumerate(inputs): 3937 4040
# In for ix, in_ in enumerate(inputs): 3938 4040
# In for ix, in_ in enumerate(inputs): 3939 4040
# In for ix, in_ in enumerate(inputs): 3940 4040
# In for ix, in_ in enumerate(inputs): 3941 4040
# In for ix, in_ in enumerate(inputs): 3942 4040
# In for ix, in_ in enumerate(inputs): 3943 4040
# In for ix, in_ in enumerate(inputs): 3944 4040
# In for ix, in_ in enumerate(inputs): 3945 4040
# In for ix, in_ in enumerate(inputs): 3946 4040
# In for ix, in_ in enumerate(inputs): 3947 4040
# In for ix, in_ in enumerate(inputs): 3948 4040
# In for ix, in_ in enumerate(inputs): 3949 4040
# In for ix, in_ in enumerate(inputs): 3950 4040
# In for ix, in_ in enumerate(inputs): 3951 4040
# In for ix, in_ in enumerate(inputs): 3952 4040
# In for ix, in_ in enumerate(inputs): 3953 4040
# In for ix, in_ in enumerate(inputs): 3954 4040
# In for ix, in_ in enumerate(inputs): 3955 4040
# In for ix, in_ in enumerate(inputs): 3956 4040
# In for ix, in_ in enumerate(inputs): 3957 4040
# In for ix, in_ in enumerate(inputs): 3958 4040
# In for ix, in_ in enumerate(inputs): 3959 4040
# In for ix, in_ in enumerate(inputs): 3960 4040
# In for ix, in_ in enumerate(inputs): 3961 4040
# In for ix, in_ in enumerate(inputs): 3962 4040
# In for ix, in_ in enumerate(inputs): 3963 4040
# In for ix, in_ in enumerate(inputs): 3964 4040
# In for ix, in_ in enumerate(inputs): 3965 4040
# In for ix, in_ in enumerate(inputs): 3966 4040
# In for ix, in_ in enumerate(inputs): 3967 4040
# In for ix, in_ in enumerate(inputs): 3968 4040
# In for ix, in_ in enumerate(inputs): 3969 4040
# In for ix, in_ in enumerate(inputs): 3970 4040
# In for ix, in_ in enumerate(inputs): 3971 4040
# In for ix, in_ in enumerate(inputs): 3972 4040
# In for ix, in_ in enumerate(inputs): 3973 4040
# In for ix, in_ in enumerate(inputs): 3974 4040
# In for ix, in_ in enumerate(inputs): 3975 4040
# In for ix, in_ in enumerate(inputs): 3976 4040
# In for ix, in_ in enumerate(inputs): 3977 4040
# In for ix, in_ in enumerate(inputs): 3978 4040
# In for ix, in_ in enumerate(inputs): 3979 4040
# In for ix, in_ in enumerate(inputs): 3980 4040
# In for ix, in_ in enumerate(inputs): 3981 4040
# In for ix, in_ in enumerate(inputs): 3982 4040
# In for ix, in_ in enumerate(inputs): 3983 4040
# In for ix, in_ in enumerate(inputs): 3984 4040
# In for ix, in_ in enumerate(inputs): 3985 4040
# In for ix, in_ in enumerate(inputs): 3986 4040
# In for ix, in_ in enumerate(inputs): 3987 4040
# In for ix, in_ in enumerate(inputs): 3988 4040
# In for ix, in_ in enumerate(inputs): 3989 4040
# In for ix, in_ in enumerate(inputs): 3990 4040
# In for ix, in_ in enumerate(inputs): 3991 4040
# In for ix, in_ in enumerate(inputs): 3992 4040
# In for ix, in_ in enumerate(inputs): 3993 4040
# In for ix, in_ in enumerate(inputs): 3994 4040
# In for ix, in_ in enumerate(inputs): 3995 4040
# In for ix, in_ in enumerate(inputs): 3996 4040
# In for ix, in_ in enumerate(inputs): 3997 4040
# In for ix, in_ in enumerate(inputs): 3998 4040
# In for ix, in_ in enumerate(inputs): 3999 4040
# In for ix, in_ in enumerate(inputs): 4000 4040
# In for ix, in_ in enumerate(inputs): 4001 4040
# In for ix, in_ in enumerate(inputs): 4002 4040
# In for ix, in_ in enumerate(inputs): 4003 4040
# In for ix, in_ in enumerate(inputs): 4004 4040
# In for ix, in_ in enumerate(inputs): 4005 4040
# In for ix, in_ in enumerate(inputs): 4006 4040
# In for ix, in_ in enumerate(inputs): 4007 4040
# In for ix, in_ in enumerate(inputs): 4008 4040
# In for ix, in_ in enumerate(inputs): 4009 4040
# In for ix, in_ in enumerate(inputs): 4010 4040
# In for ix, in_ in enumerate(inputs): 4011 4040
# In for ix, in_ in enumerate(inputs): 4012 4040
# In for ix, in_ in enumerate(inputs): 4013 4040
# In for ix, in_ in enumerate(inputs): 4014 4040
# In for ix, in_ in enumerate(inputs): 4015 4040
# In for ix, in_ in enumerate(inputs): 4016 4040
# In for ix, in_ in enumerate(inputs): 4017 4040
# In for ix, in_ in enumerate(inputs): 4018 4040
# In for ix, in_ in enumerate(inputs): 4019 4040
# In for ix, in_ in enumerate(inputs): 4020 4040
# In for ix, in_ in enumerate(inputs): 4021 4040
# In for ix, in_ in enumerate(inputs): 4022 4040
# In for ix, in_ in enumerate(inputs): 4023 4040
# In for ix, in_ in enumerate(inputs): 4024 4040
# In for ix, in_ in enumerate(inputs): 4025 4040
# In for ix, in_ in enumerate(inputs): 4026 4040
# In for ix, in_ in enumerate(inputs): 4027 4040
# In for ix, in_ in enumerate(inputs): 4028 4040
# In for ix, in_ in enumerate(inputs): 4029 4040
# In for ix, in_ in enumerate(inputs): 4030 4040
# In for ix, in_ in enumerate(inputs): 4031 4040
# In for ix, in_ in enumerate(inputs): 4032 4040
# In for ix, in_ in enumerate(inputs): 4033 4040
# In for ix, in_ in enumerate(inputs): 4034 4040
# In for ix, in_ in enumerate(inputs): 4035 4040
# In for ix, in_ in enumerate(inputs): 4036 4040
# In for ix, in_ in enumerate(inputs): 4037 4040
# In for ix, in_ in enumerate(inputs): 4038 4040
# In for ix, in_ in enumerate(inputs): 4039 4040
# "\nfor i in range(len(input_images)):\n    print 'prediction shape:', prediction[i].shape\n    plt.figure()\n    plt.plot(prediction[i])\n    plt.title('Image %d: %s - Predicted Class: %d'%(i, os.path.basename(image_subset[i]), prediction[i].argmax()))\n    print 'predicted class:', prediction[i].argmax()\n    print 'class score', max(prediction[i])\n"

# %%
predicted_classes = np.argmax(prediction, axis = 1)

# %%
print 'mean:', np.mean(df.class_id == predicted_classes)
print 'standard error:', np.std(df.class_id == predicted_classes)/np.sqrt(len(input_images))
# Out:
# mean: 0.0549504950495
# standard error: 0.00358527441205

# %%
net.blobs['data']

# %% [markdown]
# You can see that the prediction is 1000-dimensional, and is pretty sparse.
#
# The predicted class 281 is "Tabby cat." Our pretrained model uses the synset ID ordering of the classes, as listed in ../data/ilsvrc12/synset_words.txt if you fetch the auxiliary imagenet data by ../data/ilsvrc12/get_ilsvrc_aux.sh. If you look at the top indices that maximize the prediction score, they are cats, foxes, and other cute mammals. Not unreasonable predictions, right?
#
# Now let's classify by the center crop alone by turning off oversampling. Note that this makes a single input, although if you inspect the model definition prototxt you'll see the network has a batch size of 10. The python wrapper handles batching and padding for you!

# %%
prediction = net.predict([input_image], oversample=False)
print 'prediction shape:', prediction[0].shape
plt.plot(prediction[0])
print 'predicted class:', prediction[0].argmax()
# Out:
# In for ix, in_ in enumerate(inputs): 0 1
# prediction shape: (101,)
# predicted class: 81

# %% [markdown]
# Now, why don't we see how long it takes to perform the classification end to end? This result is run from an Intel i5 CPU, so you may observe some performance differences.

# %%
# %timeit net.predict([input_image])
# Out:
# In for ix, in_ in enumerate(inputs): 0 1
# In for ix, in_ in enumerate(inputs): 0 1
# In for ix, in_ in enumerate(inputs): 0 1
# In for ix, in_ in enumerate(inputs): 0 1
# 1 loops, best of 3: 283 ms per loop

# %% [markdown]
# 1 loops, best of 3: 355 ms per loop
#
# It may look a little slow, but note that time is spent on cropping, python interfacing, and running 10 images. For performance, if you really want to make prediction fast, you can optionally code in C++ and pipeline operations better. For experimenting and prototyping the current speed is fine.
#
# Let's time classifying a single image with input preprocessed:

# %%
# Resize the image to the standard (256, 256) and oversample net input sized crops.
input_oversampled = caffe.io.oversample([caffe.io.resize_image(input_image, net.image_dims)], net.crop_dims)
# 'data' is the input blob name in the model definition, so we preprocess for that input.
caffe_input = np.asarray([net.preprocess('data', in_) for in_ in input_oversampled])
# forward() takes keyword args for the input blobs with preprocessed input arrays.
# %timeit net.forward(data=caffe_input)
# Out:
# 1 loops, best of 3: 3.72 s per loop

# %%
caffe.set_mode_gpu()

# %% [markdown]
# Voila! Now we are in GPU mode. Let's see if the code gives the same result:

# %%
prediction = net.predict([input_image])
print 'prediction shape:', prediction[0].shape
plt.plot(prediction[0])
# Out:
# In for ix, in_ in enumerate(inputs): 0 1
# prediction shape: (101,)

# %% [markdown]
# Good, everything is the same. And how about time consumption? The following benchmark is obtained on the same machine with a GTX 770 GPU:

# %%
# Full pipeline timing.
# %timeit net.predict([input_image])
# Out:
# 10 loops, best of 3: 80.8 ms per loop

# %%
# Forward pass timing.
# %timeit net.forward(data=caffe_input)
# Out:
# 10 loops, best of 3: 63 ms per loop

# %% [markdown]
# Pretty fast right? Not as fast as you expected? Indeed, in this python demo you are seeing only 4 times speedup. But remember - the GPU code is actually very fast, and the data loading, transformation and interfacing actually start to take more time than the actual conv. net computation itself!
#
# To fully utilize the power of GPUs, you really want to:
#
# Use larger batches, and minimize python call and data transfer overheads.
# Pipeline data load operations, like using a subprocess.
# Code in C++. A little inconvenient, but maybe worth it if your dataset is really, really large.
# Parting Words
# So this is python! We hope the interface is easy enough for one to use. The python wrapper is interfaced with boost::python, and source code can be found at python/caffe with the main interface in pycaffe.py and the classification wrapper in classifier.py. If you have customizations to make, start there! Do let us know if you make improvements by sending a pull request!
