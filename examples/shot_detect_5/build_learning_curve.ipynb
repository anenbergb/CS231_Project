# %%
# !./extract_multiple.sh
# Out:
# working on 13000
# E0315 14:30:02.142243 11470 extract_features.cpp:54] Using GPU
# E0315 14:30:02.142740 11470 extract_features.cpp:60] Using Device_id=2
# E0315 14:30:02.984418 11470 upgrade_proto.cpp:618] Attempting to upgrade input file specified using deprecated V1LayerParameter: ./quick_train_test.prototxt
# F0315 14:30:06.806650 11470 db.cpp:27] Check failed: mkdir(source.c_str(), 0744) == 0 (-1 vs. 0) mkdir ./extracted/fine_train_features_13000/failed
# *** Check failure stack trace: ***
#     @     0x7fcb8e904b7d  google::LogMessage::Fail()
#     @     0x7fcb8e906c7f  google::LogMessage::SendToLog()
#     @     0x7fcb8e90476c  google::LogMessage::Flush()
#     @     0x7fcb8e90751d  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7fcb8ed50ba0  caffe::db::LMDB::Open()
#     @           0x4086f9  feature_extraction_pipeline<>()
#     @     0x7fcb8db3876d  (unknown)
#     @           0x403ee9  (unknown)
# ...

# %%
# !rmdir extracted/fine_train_features_13000/
# Out:
# rmdir: failed to remove `extracted/fine_train_features_13000/': Directory not empty

# %%
rm -rf fine_train_features_13000/

# %%
ls -lha snapshots/fine*
# Out:
# -rw-r--r-- 1 anenberg users 219M Mar 14 22:30 snapshots/fine_iter_10000.caffemodel
# -rw-r--r-- 1 anenberg users 219M Mar 14 22:31 snapshots/fine_iter_10000.solverstate
# -rw-r--r-- 1 anenberg users 219M Mar 14 20:31 snapshots/fine_iter_1000.caffemodel
# -rw-r--r-- 1 anenberg users 219M Mar 14 20:31 snapshots/fine_iter_1000.solverstate
# -rw-r--r-- 1 anenberg users 219M Mar 14 22:52 snapshots/fine_iter_11000.caffemodel
# -rw-r--r-- 1 anenberg users 219M Mar 14 22:53 snapshots/fine_iter_11000.solverstate
# -rw-r--r-- 1 anenberg users 219M Mar 14 23:13 snapshots/fine_iter_12000.caffemodel
# -rw-r--r-- 1 anenberg users 219M Mar 14 23:14 snapshots/fine_iter_12000.solverstate
# -rw-r--r-- 1 anenberg users 219M Mar 14 23:34 snapshots/fine_iter_13000.caffemodel
# -rw-r--r-- 1 anenberg users 219M Mar 14 23:34 snapshots/fine_iter_13000.solverstate
# -rw-r--r-- 1 anenberg users 219M Mar 14 23:54 snapshots/fine_iter_14000.caffemodel
# ...

# %%
ls extracted/
# Out:
# features1/           fine_features_4000/        fine_train_features_3000/
# fine_features_1000/  fine_features_5000/        fine_train_features_4000/
# fine_features_2000/  fine_train_features_1000/  fine_train_features_5000/
# fine_features_3000/  fine_train_features_2000/  fine_train_features_6000/

# %%
finished 12000
