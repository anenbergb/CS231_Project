# %% [raw]
# Brox optical flow

# %%
! ./OpenCV/brox_optical_flow help
# Out:
# Usage: brox_optical_flow [options]
# Avaible options:
#   -a, --alpha=[0.197]         set alpha
#   -g, --gamma=[50.0]          set gamma
#   -h, --help=[true]           print help message
#   -i, --inner=[10]            set number of inner iterations
#   -l, --left                  specify left image
#   -o, --outer=[77]            set number of outer iterations
#   -r, --right                 specify right image
#   -s, --scale=[0.8]           set pyramid scale factor
#   -si, --solver=[10]          set number of basic solver iterations
#   -t, --time_step=[0.1]       set frame interpolation time step

# %%
# %%bash
# left=/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train/video_validation_0000006/00000500.jpg
# right=/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train/video_validation_0000006/00000501.jpg
# ./OpenCV/brox_optical_flow -l $left -r $right -sa ./opticalflow_ -GPU 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os, subprocess, pickle
import matplotlib.image as mpimg
def printIm(im_path, frameNum):
    num = '%08d.jpg'%frameNum
    frame_path = im_path+num
    img = mpimg.imread(frame_path)
    plt.imshow(img, origin="lower")
    #plt.gca().axis('off')
    #plt.gcf().set_size_inches((2, 2))
    #plt.show()

def showIm(image):
    img = mpimg.imread(image)
    plt.imshow(img,origin="lower")
    plt.gca().axis('off')
    plt.gcf().set_size_inches((2, 2))
    plt.colorbar()
    plt.show()

im_path = "/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train/video_validation_0000006/"
printIm(im_path,500)

# %%
#showIm("opticalflow_dX.jpg")

# %%
showIm("opticalflow_dY.jpg")

# %%
import os, subprocess, pickle


def opticalFlow(frame1, frame2, savePath, GPU=1):
    """
    computes the optical flow between frames 1 and 2.
    Saves the two optical flow images (dX and dY) at the
    target location: savePathdX and savePathdY
    
    GPU: the number of the GPU to run on 
    """
    #Returns the duration of the video in seconds.
    if not os.path.exists(frame1):
        print '%s does not exist!' % frame1
        return False
    if not os.path.exists(frame2):
        print '%s does not exist!' % frame2
        return False
    
    brox_optical_flow = '/afs/cs.stanford.edu/u/anenberg/scr/CS231N/code/OpenCV/brox_optical_flow'
    p = subprocess.Popen([brox_optical_flow, '-l', frame1, '-r', frame2, '-sa', \
                          savePath, '-GPU', str(GPU)], stdout=subprocess.PIPE,stderr=subprocess.PIPE)
    out, err = p.communicate()
    print out, err
    return True

# %%
left="/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train/video_validation_0000006/00000500.jpg"
right="/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train/video_validation_0000006/00000530.jpg"
saveLocation="./opticalFlow"
opticalFlow(left,right,saveLocation)
# Out:
# /afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train/video_validation_0000006/00000530.jp does not exist!
# False

# %%
showIm("opticalFlowdX.jpg")
showIm("opticalFlowdY.jpg")

# %%
showIm(left)
showIm(right)

# %% [raw]
# Printing some of the images norman generated in the home directory CS231N/optical_flow_images

# %%
showIm("../optical_flow_images/v_ApplyEyeMakeup_g01_c04_00000077dY.jpg")

# %%
!
