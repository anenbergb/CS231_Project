# %%
import os, csv, pickle, subprocess

# %%
class_index = pickle.load( open("class_index.pkl", "rb" ) )

# %%
def noPklList(directory):
    noPkls = []
    for d in os.listdir(directory):
        ts_file = os.path.join(os.path.join(directory,d),"time_stamp_map.pkl")
        out = os.path.exists(ts_file)
        noPkls.append(out)
    return noPkls

# %%
noPkls = noPklList("/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/")

# %%
noPklFalse = [a for a in noPkls if a==False]

# %%
noPklFalse
# Out:
# []

# %%
# !ls ../allFrames/Test/video_test_0000001/time_stamp_map.pkl
# Out:
# ../allFrames/Test/video_test_0000001/time_stamp_map.pkl

# %%
VAL="/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/"

wcs = []
for d in os.listdir(VAL):
    wc = subprocess.check_output("ls %s | wc -l" % os.path.join(VAL,d),shell=True)
    wcs.append(wc)
wcs = map(lambda x: int(x.strip()),wcs)
wcs = sorted(wcs,reverse=True)
# Out:
# '9806\n'

# %%
# !ls /afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/ | wc -l
# !ls /afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/videos/ | wc -l
# !ls /afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Training/Frames/ | wc -l

# !ls /afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Test/Frames/ | wc -l
# !ls /afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Test/videos/ | wc -l
# Out:
# 1001
# 1010
# 13320
# 1570
# 1574

# %%
os.path.exists("/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/video_validation_0000887/time_stamp_map.pkl")
# Out:
# True

# %%
! ls ../allFrames/Train/ | wc -l
# Out:
# 14320

# %%
toListFile = [("frame1",1),("frame2",2)]
fileToWriteTo = "./AWESOME.txt"
with open(fileToWriteTo,'wb') as f:
    out = csv.writer(f, delimiter=' ')
    for frame, index in toListFile:
        out.writerow([frame, index])

# %%
# %%bash --out output --err error
# ls $video_name
# Out:
# detection_class_index.pkl
# makeDetectionIndexMap.py
# makeLists.py
# makeVid_class_index_map.py
# prepareData.sh
# QuickTransforms.ipynb
# README.md
# TEST_TSmap.pkl
# TEST_vidmap.pkl
# Train_list.txt
# UCF_vidmap.pkl
# VALID_TSmap.pkl
# VALID_vidmap.pkl

# %%
#! echo "Hello world" > AWESOME.txt
! cat AWESOME.txt
# Out:
# frame1 1
# frame2 2

# %% [raw]
# 	Script that uses the temporal annotations to construct a map:
# 	map[videoname][time_stamp] = class_id

# %%
VID_MAPS = [Train_map,Test_map]

def makeList(data_dir,out_list, vid_map):
    toListFile = []
    for d in os.listdir(data_dir):
        
        for f in os.listdir(os.path.join(data_dir,d)):
        	if f.split('.')[1] != "pkl":
	            frame_name = d+"/"+f
	            #Now we need to know the label of this image.
	            frame_index = temporal_map[d][
	            print frame_name, frame_index
	            toListFile.append((frame_name,frame_index))

    with open(out_list,'wb') as f:
        out = csv.writer(f, delimiter=' ')
        for frame, index in toListFile:
            out.writerow([frame, index])

# %%
annotations = ["/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/annotation", \
               "/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Test/annotation"]
lists = ["./Train_list.txt","./Test_list.txt"]
for directory, out_list, vid_map in zip(annotations,lists,VID_MAPS):
      if os.path.exists(directory):
          makeList(directory,out_list,vid_map)

# %%
exampleVid = "/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/video_validation_0000003/"
example_TS_map = pickle.load( open(os.path.join(exampleVid, "time_stamp_map.pkl"),"rb"))

# %%
print min(example_TS_map.keys()), max(example_TS_map.keys())
# Out:
# 1 11509

# %%
! ls /afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/video_validation_0000003/
# Out:
# 00000001.jpg  00001440.jpg  00002879.jpg  00004318.jpg	00005757.jpg  00007196.jpg  00008635.jpg  00010074.jpg
# 00000002.jpg  00001441.jpg  00002880.jpg  00004319.jpg	00005758.jpg  00007197.jpg  00008636.jpg  00010075.jpg
# 00000003.jpg  00001442.jpg  00002881.jpg  00004320.jpg	00005759.jpg  00007198.jpg  00008637.jpg  00010076.jpg
# 00000004.jpg  00001443.jpg  00002882.jpg  00004321.jpg	00005760.jpg  00007199.jpg  00008638.jpg  00010077.jpg
# 00000005.jpg  00001444.jpg  00002883.jpg  00004322.jpg	00005761.jpg  00007200.jpg  00008639.jpg  00010078.jpg
# 00000006.jpg  00001445.jpg  00002884.jpg  00004323.jpg	00005762.jpg  00007201.jpg  00008640.jpg  00010079.jpg
# 00000007.jpg  00001446.jpg  00002885.jpg  00004324.jpg	00005763.jpg  00007202.jpg  00008641.jpg  00010080.jpg
# 00000008.jpg  00001447.jpg  00002886.jpg  00004325.jpg	00005764.jpg  00007203.jpg  00008642.jpg  00010081.jpg
# ...

# %%
UCF_vidmap = pickle.load( open("./UCF_vidmap.pkl", "rb" ) )[1]

# %%
'v_Diving_g08_c02' in UCF_vidmap.keys()
# Out:
# True

# %%
TSmapFile = "../allFrames/Train/video_validation_0001010/time_stamp_map.pkl"
TSmap = pickle.load( open(TSmapFile, "rb" ) )

# %%
import pickle, os
detection_class_index = pickle.load( open("./detection_class_index.pkl", "rb" ) )
UCF_DIR="/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Training/Frames/"
VALID_DIR="/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/"
TEST_DIR="/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Test/Frames/"
UCF_vidmap = pickle.load( open("./UCF_vidmap.pkl", "rb" ) )[1]

# %%
import collections
hist = collections.Counter()
for d in os.listdir(UCF_DIR):
    if UCF_vidmap[d] in detection_class_index[2]:
        hist[detection_class_index[2][UCF_vidmap[d]]] += 1
print hist
# Out:
# Counter({7: 167, 18: 166, 1: 150, 3: 150, 8: 150, 11: 150, 15: 149, 16: 144, 6: 139, 10: 139, 5: 138, 17: 137, 2: 131, 14: 131, 19: 130, 9: 126, 12: 123, 13: 117, 20: 116, 4: 112})

# %%
max(hist)
# Out:
# 20

# %%
detection_videos = [d for d in os.listdir(UCF_DIR) if UCF_vidmap[d] in detection_class_index[2]]
len(detection_videos)
# Out:
# 2765

# %%
detection
# Out:
# 101

# %%
VALID_vidmap = pickle.load( open("./VALID_vidmap.pkl", "rb") )[1]
detection_videos = [d for d in os.listdir(VALID_DIR) if VALID_vidmap[d] in detection_class_index[2]]
len(detection_videos)
# Out:
# 200

# %%
video="/afs/cs.stanford.edu/group/cvgl/rawdata/THUMOS2014/Validation/Frames/video_validation_0000003/"
frame_to_TS_map = pickle.load( open(os.path.join(video, "time_stamp_map.pkl"),"rb"))

# %%
for i, e in enumerate(xrange(5,10)):
    print i, e
# Out:
# 0 5
# 1 6
# 2 7
# 3 8
# 4 9

# %%
VALID_TSmap = pickle.load( open("./VALID_TSmap.pkl", "rb" ) )

# %%
len(VALID_TSmap)
# Out:
# 200

# %%
#TEST_TSmap = pickle.load( open("./TEST_TSmap.pkl", "rb" ) )
len(TEST_TSmap)
# Out:
# 212

# %%
for vid,key in TEST_TSmap.iteritems():
    labels = len(set([t[1] for t in key.items()]))
    print "%s: %d"%(vid,labels)
# Out:
# video_test_0001313: 2
# video_test_0000896: 1
# video_test_0000897: 1
# video_test_0000950: 1
# video_test_0000844: 1
# video_test_0001079: 1
# video_test_0001078: 1
# video_test_0000179: 1
# video_test_0000839: 1
# video_test_0000173: 1
# video_test_0001072: 1
# video_test_0001075: 1
# video_test_0000767: 1
# video_test_0001076: 1
# video_test_0000007: 1
# video_test_0000006: 1
# video_test_0000556: 1
# video_test_0001307: 1
# video_test_0001153: 1
# video_test_0000718: 1
# video_test_0000716: 1
# video_test_0001309: 1
# video_test_0000714: 1
# video_test_0000558: 1
# video_test_0001267: 1
# video_test_0000367: 3
# video_test_0001496: 1
# video_test_0000085: 1
# video_test_0000887: 1
# video_test_0001209: 1
# video_test_0001281: 1
# video_test_0000882: 1
# video_test_0000671: 1
# video_test_0000964: 1
# video_test_0001164: 2
# video_test_0001114: 1
# video_test_0000807: 1
# video_test_0001163: 1
# video_test_0001118: 1
# video_test_0001201: 1
# video_test_0001040: 1
# ...

# %%
TEST_TSmap['video_test_0000036']
# Out:
# {}

# %%
'video_test_0001146' in  TEST_TSmap
# Out:
# True

# %%
TEST_vidmap = pickle.load( open("./TEST_vidmap.pkl", "rb") )[1]

# %%
TEST_vidmap['video_test_0000036']
# Out:
# 40
