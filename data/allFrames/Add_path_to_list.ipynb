# %%
import pandas as pd
import os, csv
import numpy as np

experiment_dir = '/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/lists'
data_paths = ['/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/test','/afs/cs.stanford.edu/u/anenberg/scr/CS231N/data/allFrames/train']
filenames = ["shuffle_shotdetect_sampled_t2_100_test_list.txt", "shuffle_shotdetect_sampled_t2_100_train_list.txt"]

# %%
# load data

for filename, data_path in zip(filenames,data_paths):
    output_file = 'fullpath_%s'%(filename)
    fullpath_filename = os.path.join(experiment_dir,filename)
    fullpath_output_file = os.path.join(experiment_dir,output_file)
    with open(fullpath_filename,'rb') as f:
        reader = csv.reader(f, delimiter=' ')
        with open(fullpath_output_file,'wb') as f2:
            out = csv.writer(f2, delimiter=' ')
            for row in reader:
                image_path = os.path.join(data_path,row[0])
                out.writerow([image_path, row[1]])

# %%
#! cat ./lists/fullpath_shuffle_shotdetect_sampled_5_test_list.txt

# %%
# !ls ./lists/
# Out:
# fullpath_shuffle_sampled_100_test_list.txt		 shuffle_sampled_test_list.txt
# fullpath_shuffle_sampled_100_train_list.txt		 shuffle_sampled_train_list.txt
# fullpath_shuffle_shotdetect_sampled_100_test_list.txt	 shuffle_shotdetect_sampled_100_test_list.txt
# fullpath_shuffle_shotdetect_sampled_100_train_list.txt	 shuffle_shotdetect_sampled_100_train_list.txt
# fullpath_shuffle_shotdetect_sampled_5_test_list.txt	 shuffle_shotdetect_sampled_5_test_list.txt
# fullpath_shuffle_shotdetect_sampled_5_train_list.txt	 shuffle_shotdetect_sampled_5_train_list.txt
# fullpath_shuffle_shotdetect_sampled_t2_5_test_list.txt	 shuffle_shotdetect_sampled_t2_5_test_list.txt
# fullpath_shuffle_shotdetect_sampled_t2_5_train_list.txt  shuffle_shotdetect_sampled_t2_5_train_list.txt
# sampled_test_list.txt					 test_list.txt
# sampled_train_list.txt					 test_list.txt.small
# shuffle_sampled_100_test_list.txt			 train_list.txt
# shuffle_sampled_100_test_list.txt_shotdetect		 train_list.txt.small
# shuffle_sampled_100_train_list.txt			 UCF_test_list.txt
# shuffle_sampled_100_train_list.txt.small		 UCF_train_list.txt
# shuffle_sampled_100_train_list.txt.small_shotdetect
